# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel("tourismData.xlsx",'Tourism')
data = data[['CustomerID','ProdTaken']] 
data
# Out:
#       CustomerID  ProdTaken
# 0         200000          1
# 1         200001          0
# 2         200002          1
# 3         200003          0
# 4         200004          0
# ...          ...        ...
# 4883      204883          1
# 4884      204884          1
# 4885      204885          1
# 4886      204886          1
# 4887      204887          1
#
# [4888 rows x 2 columns]

# %%
data.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisited',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisited', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
data = data[['Age', 'TypeofContact', 'CityTier', 'DurationOfPitch', 'Occupation',
       'Gender', 'NumberOfPersonVisited', 'NumberOfFollowups',
       'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
       'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
       'NumberOfChildrenVisited', 'Designation', 'MonthlyIncome', 'ProdTaken']]
# Out:
#     Age    TypeofContact  CityTier  DurationOfPitch      Occupation  Gender  \
# 0  41.0     Self Enquiry         3              6.0        Salaried  Female
# 1  49.0  Company Invited         1             14.0        Salaried    Male
# 2  37.0     Self Enquiry         1              8.0     Free Lancer    Male
# 3  33.0  Company Invited         1              9.0        Salaried  Female
# 4   NaN     Self Enquiry         1              8.0  Small Business    Male
#
#    NumberOfPersonVisited  NumberOfFollowups ProductPitched  \
# 0                      3                3.0         Deluxe
# 1                      3                4.0         Deluxe
# 2                      3                4.0          Basic
# 3                      2                3.0          Basic
# 4                      2                3.0          Basic
#
#    PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 0                    3.0        Single            1.0         1
# 1                    4.0      Divorced            2.0         0
# 2                    3.0        Single            7.0         1
# 3                    3.0      Divorced            2.0         1
# 4                    4.0      Divorced            1.0         0
#
#    PitchSatisfactionScore  OwnCar  NumberOfChildrenVisited Designation  \
# 0                       2       1                      0.0     Manager
# 1                       3       1                      2.0     Manager
# 2                       3       0                      0.0   Executive
# 3                       5       1                      1.0   Executive
# 4                       5       1                      0.0   Executive
#
#    MonthlyIncome  ProdTaken
# 0        20993.0          1
# 1        20130.0          0
# 2        17090.0          1
# 3        17909.0          0
# 4        18468.0          0

# %%
cat_col = [feature for feature in data.columns if data[feature].dtype == 'O']

# %%
num_col = [feature for feature in data.columns if data[feature].dtype != 'O']

# %%
data.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisited',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisited  NumberOfFollowups  ...  \
# 0           Salaried  Female                      3                3.0  ...
# 1           Salaried    Male                      3                4.0  ...
# 2        Free Lancer    Male                      3                4.0  ...
# 3           Salaried  Female                      2                3.0  ...
# 4     Small Business    Male                      2                3.0  ...
# ...              ...     ...                    ...                ...  ...
# 4883  Small Business    Male                      3                5.0  ...
# 4884        Salaried    Male                      4                5.0  ...
# 4885        Salaried  Female                      4                4.0  ...
# 4886  Small Business    Male                      3                4.0  ...
# 4887        Salaried    Male                      4                4.0  ...
#
#      PreferredPropertyStar  MaritalStatus NumberOfTrips  Passport  \
# 0                      3.0         Single           1.0         1
# 1                      4.0       Divorced           2.0         0
# 2                      3.0         Single           7.0         1
# 3                      3.0       Divorced           2.0         1
# 4                      4.0       Divorced           1.0         0
# ...                    ...            ...           ...       ...
# 4883                   4.0      Unmarried           2.0         1
# 4884                   3.0         Single           3.0         1
# 4885                   4.0        Married           7.0         0
# 4886                   3.0         Single           3.0         0
# 4887                   4.0      Unmarried           3.0         1
#
#       PitchSatisfactionScore  OwnCar  NumberOfChildrenVisited     Designation  \
# 0                          2       1                      0.0         Manager
# 1                          3       1                      2.0         Manager
# 2                          3       0                      0.0       Executive
# 3                          5       1                      1.0       Executive
# 4                          5       1                      0.0       Executive
# ...                      ...     ...                      ...             ...
# 4883                       1       1                      1.0         Manager
# 4884                       3       1                      2.0       Executive
# 4885                       1       1                      3.0  Senior Manager
# 4886                       5       0                      2.0       Executive
# 4887                       3       1                      2.0       Executive
#
#      MonthlyIncome  NumberOfChildrenVisited
# 0          20993.0                      0.0
# 1          20130.0                      2.0
# 2          17090.0                      0.0
# 3          17909.0                      1.0
# 4          18468.0                      0.0
# ...            ...                      ...
# 4883       26576.0                      1.0
# 4884       21212.0                      2.0
# 4885       31820.0                      3.0
# 4886       20289.0                      2.0
# 4887       24041.0                      2.0
#
# [4888 rows x 21 columns]

# %%
data.isna().sum()
# Out:
# Age                        226
# TypeofContact               25
# CityTier                     0
# DurationOfPitch            251
# Occupation                   0
# Gender                       0
# NumberOfPersonVisited        0
# NumberOfFollowups           45
# ProductPitched               0
# PreferredPropertyStar       26
# MaritalStatus                0
# NumberOfTrips              140
# Passport                     0
# PitchSatisfactionScore       0
# OwnCar                       0
# NumberOfChildrenVisited     66
# Designation                  0
# MonthlyIncome              233
# ProdTaken                    0
# dtype: int64

# %%
nullValues = [feature for feature in data.columns if data[feature].isna().sum()>0]

nullValues
# Out:
# ['Age',
#  'TypeofContact',
#  'DurationOfPitch',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'NumberOfChildrenVisited',
#  'MonthlyIncome']

# %%
data[nullValues].dtypes
# Out:
# Age                        float64
# TypeofContact               object
# DurationOfPitch            float64
# NumberOfFollowups          float64
# PreferredPropertyStar      float64
# NumberOfTrips              float64
# NumberOfChildrenVisited    float64
# MonthlyIncome              float64
# dtype: object

# %%
for i in data[nullValues].columns:
    print(i)
    print(data[i].unique())
    print()
# Out:
# Age
# [41. 49. 37. 33. nan 32. 59. 30. 38. 36. 35. 31. 34. 28. 29. 22. 53. 21.
#  42. 44. 46. 39. 24. 43. 50. 27. 26. 48. 55. 45. 56. 23. 51. 40. 54. 58.
#  20. 25. 19. 57. 52. 47. 18. 60. 61.]
#
# TypeofContact
# ['Self Enquiry' 'Company Invited' nan]
#
# DurationOfPitch
# [  6.  14.   8.   9.  30.  29.  33.  22.  21.  32.  25.  27.  11.  17.
#   15.  13.  12.  16.  10.  31.  18.  nan  24.  35.  28.  20.  26.  34.
#   23.   5.  19. 126.   7.  36. 127.]
#
# NumberOfFollowups
# [ 3.  4.  2.  5. nan  1.  6.]
#
# PreferredPropertyStar
# [ 3.  4.  5. nan]
#
# NumberOfTrips
# [ 1.  2.  7.  5.  6.  3.  4. 19. 21.  8. nan 20. 22.]
#
# NumberOfChildrenVisited
# [ 0.  2.  1. nan  3.]
#
# MonthlyIncome
# [20993. 20130. 17090. ... 22097. 22995. 21471.]

# %%
nullValues
# Out:
# ['Age',
#  'TypeofContact',
#  'DurationOfPitch',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'NumberOfChildrenVisited',
#  'MonthlyIncome']

# %%
data['Age'].fillna(data['Age'].median(),inplace=True) 
data['TypeofContact'].fillna(data['TypeofContact'].mode()[0],inplace=True)
data['DurationOfPitch'].fillna(data['DurationOfPitch'].median(),inplace=True)
data['NumberOfFollowups'].fillna(data['NumberOfFollowups'].median(),inplace=True)
data['PreferredPropertyStar'].fillna(data['PreferredPropertyStar'].median(),inplace=True)
data['NumberOfTrips'].fillna(data['NumberOfTrips'].median(),inplace=True)
data['NumberOfChildrenVisited'].fillna(data['NumberOfChildrenVisited'].median(),inplace=True)
data['MonthlyIncome'].fillna(data['MonthlyIncome'].median(),inplace=True)


data.isna().sum()
# Out:
# Age                        0
# TypeofContact              0
# CityTier                   0
# DurationOfPitch            0
# Occupation                 0
# Gender                     0
# NumberOfPersonVisited      0
# NumberOfFollowups          0
# ProductPitched             0
# PreferredPropertyStar      0
# MaritalStatus              0
# NumberOfTrips              0
# Passport                   0
# PitchSatisfactionScore     0
# OwnCar                     0
# NumberOfChildrenVisited    0
# Designation                0
# MonthlyIncome              0
# ProdTaken                  0
# dtype: int64

# %%
data.describe().T
# Out:
#                           count          mean          std     min      25%  \
# Age                      4888.0     37.547259     9.104795    18.0     31.0
# CityTier                 4888.0      1.654255     0.916583     1.0      1.0
# DurationOfPitch          4888.0     15.362930     8.316166     5.0      9.0
# NumberOfPersonVisited    4888.0      2.905074     0.724891     1.0      2.0
# NumberOfFollowups        4888.0      3.711129     0.998271     1.0      3.0
# PreferredPropertyStar    4888.0      3.577946     0.797005     3.0      3.0
# NumberOfTrips            4888.0      3.229746     1.822769     1.0      2.0
# Passport                 4888.0      0.290917     0.454232     0.0      0.0
# PitchSatisfactionScore   4888.0      3.078151     1.365792     1.0      2.0
# OwnCar                   4888.0      0.620295     0.485363     0.0      0.0
# NumberOfChildrenVisited  4888.0      1.184738     0.852323     0.0      1.0
# MonthlyIncome            4888.0  23559.179419  5257.862921  1000.0  20485.0
# ProdTaken                4888.0      0.188216     0.390925     0.0      0.0
#
#                              50%       75%      max
# Age                         36.0     43.00     61.0
# CityTier                     1.0      3.00      3.0
# DurationOfPitch             13.0     19.00    127.0
# NumberOfPersonVisited        3.0      3.00      5.0
# NumberOfFollowups            4.0      4.00      6.0
# PreferredPropertyStar        3.0      4.00      5.0
# NumberOfTrips                3.0      4.00     22.0
# Passport                     0.0      1.00      1.0
# PitchSatisfactionScore       3.0      4.00      5.0
# OwnCar                       1.0      1.00      1.0
# NumberOfChildrenVisited      1.0      2.00      3.0
# MonthlyIncome            22347.0  25424.75  98678.0
# ProdTaken                    0.0      0.00      1.0

# %%
data = data[['Age', 'TypeofContact', 'CityTier',
       'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisited',
       'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
       'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
       'OwnCar', 'NumberOfChildrenVisited', 'Designation', 'MonthlyIncome','ProdTaken']]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(),cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %%
CatFr = [feature for feature in data.columns if data[feature].dtype == 'O']
NumFr = [feature for feature in data.columns if data[feature].dtype != 'O']
print("Cat feature :", len(CatFr))
print("Num feature :", len(NumFr))
# Out:
# Cat feature : 6
# Num feature : 13

# %%
smallValueFeature = ['TypeofContact','Occupation','Gender','ProductPitched','MaritalStatus','Designation',
                     'CityTier','NumberOfPersonVisited','NumberOfFollowups','PreferredPropertyStar',
                     'Passport','PitchSatisfactionScore','OwnCar','NumberOfChildrenVisited']

longValueFeature = ['Age','DurationOfPitch','NumberOfTrips','MonthlyIncome']

# %%
df=data[data.ProdTaken==1]

plt.figure(figsize=(15,22))
for i in enumerate(smallValueFeature):
    plt.subplot(5,3,i[0]+1)
    sns.countplot(data=df,x = df['ProdTaken'],hue=df[i[1]])

# %%
data.cov()
# Out:
#                                   Age    CityTier  DurationOfPitch  \
# Age                         82.897296   -0.106432        -0.474082
# CityTier                    -0.106432    0.840125         0.148220
# DurationOfPitch             -0.474082    0.148220        69.158617
# NumberOfPersonVisited        0.117849   -0.001110         0.441048
# NumberOfFollowups            0.015291    0.022265         0.128802
# PreferredPropertyStar       -0.115614   -0.006194        -0.036070
# NumberOfTrips                2.899208   -0.048031         0.214534
# Passport                     0.133988    0.000747         0.126645
# PitchSatisfactionScore       0.216277   -0.052778        -0.028983
# OwnCar                       0.209272    0.001698        -0.010109
# NumberOfChildrenVisited      0.065853    0.000452         0.270161
# MonthlyIncome            22082.387570  249.588135       146.247332
# ProdTaken                   -0.511659    0.031120         0.248640
#
#                          NumberOfPersonVisited  NumberOfFollowups  \
# Age                                   0.117849           0.015291
# CityTier                             -0.001110           0.022265
# DurationOfPitch                       0.441048           0.128802
# NumberOfPersonVisited                 0.525466           0.235106
# NumberOfFollowups                     0.235106           0.996545
# PreferredPropertyStar                 0.017632          -0.021473
# NumberOfTrips                         0.251198           0.245836
# Passport                              0.003680           0.002000
# PitchSatisfactionScore               -0.019386           0.006005
# OwnCar                                0.003646           0.005905
# NumberOfChildrenVisited               0.374610           0.239585
# MonthlyIncome                       756.362237         923.371668
# ProdTaken                             0.002728           0.043536
#
#                          PreferredPropertyStar  NumberOfTrips  Passport  \
# Age                                  -0.115614       2.899208  0.133988
# CityTier                             -0.006194      -0.048031  0.000747
# DurationOfPitch                      -0.036070       0.214534  0.126645
# NumberOfPersonVisited                 0.017632       0.251198  0.003680
# NumberOfFollowups                    -0.021473       0.245836  0.002000
# PreferredPropertyStar                 0.635216       0.013703  0.000442
# NumberOfTrips                         0.013703       3.322487  0.010702
# Passport                              0.000442       0.010702  0.206326
# PitchSatisfactionScore               -0.026146      -0.011206  0.001815
# OwnCar                                0.005252      -0.010761 -0.004923
# NumberOfChildrenVisited               0.021304       0.250161  0.007838
# MonthlyIncome                        -2.127043    1104.158280  7.960275
# ProdTaken                             0.030753       0.014044  0.046318
#
#                          PitchSatisfactionScore      OwnCar  \
# Age                                    0.216277    0.209272
# CityTier                              -0.052778    0.001698
# DurationOfPitch                       -0.028983   -0.010109
# NumberOfPersonVisited                 -0.019386    0.003646
# NumberOfFollowups                      0.006005    0.005905
# PreferredPropertyStar                 -0.026146    0.005252
# NumberOfTrips                         -0.011206   -0.010761
# Passport                               0.001815   -0.004923
# PitchSatisfactionScore                 1.865387    0.045641
# OwnCar                                 0.045641    0.235577
# NumberOfChildrenVisited                0.000293    0.010615
# MonthlyIncome                        207.588799  200.222427
# ProdTaken                              0.027440   -0.002184
#
#                          NumberOfChildrenVisited  MonthlyIncome   ProdTaken
# Age                                     0.065853   2.208239e+04   -0.511659
# CityTier                                0.000452   2.495881e+02    0.031120
# DurationOfPitch                         0.270161   1.462473e+02    0.248640
# NumberOfPersonVisited                   0.374610   7.563622e+02    0.002728
# NumberOfFollowups                       0.239585   9.233717e+02    0.043536
# PreferredPropertyStar                   0.021304  -2.127043e+00    0.030753
# NumberOfTrips                           0.250161   1.104158e+03    0.014044
# Passport                                0.007838   7.960275e+00    0.046318
# PitchSatisfactionScore                  0.000293   2.075888e+02    0.027440
# OwnCar                                  0.010615   2.002224e+02   -0.002184
# NumberOfChildrenVisited                 0.726454   8.500503e+02    0.002668
# MonthlyIncome                         850.050334   2.764512e+07 -259.846545
# ProdTaken                               0.002668  -2.598465e+02    0.152822

# %%
data['Age'].skew()
# Out:
# 0.41579605786474494

# %%
checkSkew = ['Age','CityTier','DurationOfPitch','NumberOfPersonVisited','NumberOfFollowups','PreferredPropertyStar',
 'NumberOfTrips','PitchSatisfactionScore','NumberOfChildrenVisited','MonthlyIncome']

# %%
plt.figure(figsize=(15,22))
for i in enumerate(checkSkew):
    plt.subplot(4,4,i[0]+1)
    sns.distplot(data[i[1]],kde=True)

# %%
from scipy.stats import normaltest

# %%
for i in checkSkew:
    
    print(i+" "+str(normaltest(data[i])[1]*100))
# Out:
# Age 1.4042870631749366e-33
# CityTier 0.0
# DurationOfPitch 0.0
# NumberOfPersonVisited 2.1153117393921714e-79
# NumberOfFollowups 5.047249990137504e-34
# PreferredPropertyStar 1.933730377004348e-210
# NumberOfTrips 0.0
# PitchSatisfactionScore 0.0
# NumberOfChildrenVisited 2.1970009344837837e-42
# MonthlyIncome 0.0

# %%
Outliers = ['Age','DurationOfPitch','NumberOfPersonVisited','NumberOfFollowups','PreferredPropertyStar',
 'NumberOfTrips','MonthlyIncome']


plt.figure(figsize=(20,10))
for i in enumerate(Outliers):
    plt.subplot(1,7,i[0]+1)
    sns.boxplot(y=data[i[1]])

# %%
def get_iqr(df,column_name,q1_range,q3_range):
    q1 = df[column_name].quantile(q1_range)
    q3 = df[column_name].quantile(q3_range)
    IQR = q3-q1
    upper_fence = q3 + (1.5*IQR)
    lower_fence = q1 - (1.5*IQR)
    
    return IQR,upper_fence,lower_fence

    indexUL = data[data[column_name]>upper_fence].index
    indexLM = data[data[column_name]<lower_fence].index

    data.drop(indexUL,inplace=True)
    data.drop(indexLM,inplace=True)


get_iqr(data,'MonthlyIncome',0.20,0.90)
get_iqr(data,'DurationOfPitch',0.10,0.85)
get_iqr(data,'NumberOfTrips',0.20,0.75)
# Out:
# (2.0, 7.0, -1.0)

# %%
data
# Out:
#        Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 0     41.0     Self Enquiry         3              6.0        Salaried
# 1     49.0  Company Invited         1             14.0        Salaried
# 2     37.0     Self Enquiry         1              8.0     Free Lancer
# 3     33.0  Company Invited         1              9.0        Salaried
# 4     36.0     Self Enquiry         1              8.0  Small Business
# ...    ...              ...       ...              ...             ...
# 4883  49.0     Self Enquiry         3              9.0  Small Business
# 4884  28.0  Company Invited         1             31.0        Salaried
# 4885  52.0     Self Enquiry         3             17.0        Salaried
# 4886  19.0     Self Enquiry         3             16.0  Small Business
# 4887  36.0     Self Enquiry         1             14.0        Salaried
#
#       Gender  NumberOfPersonVisited  NumberOfFollowups ProductPitched  \
# 0     Female                      3                3.0         Deluxe
# 1       Male                      3                4.0         Deluxe
# 2       Male                      3                4.0          Basic
# 3     Female                      2                3.0          Basic
# 4       Male                      2                3.0          Basic
# ...      ...                    ...                ...            ...
# 4883    Male                      3                5.0         Deluxe
# 4884    Male                      4                5.0          Basic
# 4885  Female                      4                4.0       Standard
# 4886    Male                      3                4.0          Basic
# 4887    Male                      4                4.0          Basic
#
#       PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 0                       3.0        Single            1.0         1
# 1                       4.0      Divorced            2.0         0
# 2                       3.0        Single            7.0         1
# 3                       3.0      Divorced            2.0         1
# 4                       4.0      Divorced            1.0         0
# ...                     ...           ...            ...       ...
# 4883                    4.0     Unmarried            2.0         1
# 4884                    3.0        Single            3.0         1
# 4885                    4.0       Married            7.0         0
# 4886                    3.0        Single            3.0         0
# 4887                    4.0     Unmarried            3.0         1
#
#       PitchSatisfactionScore  OwnCar  NumberOfChildrenVisited     Designation  \
# 0                          2       1                      0.0         Manager
# 1                          3       1                      2.0         Manager
# 2                          3       0                      0.0       Executive
# 3                          5       1                      1.0       Executive
# 4                          5       1                      0.0       Executive
# ...                      ...     ...                      ...             ...
# 4883                       1       1                      1.0         Manager
# 4884                       3       1                      2.0       Executive
# 4885                       1       1                      3.0  Senior Manager
# 4886                       5       0                      2.0       Executive
# 4887                       3       1                      2.0       Executive
#
#       MonthlyIncome  ProdTaken
# 0           20993.0          1
# 1           20130.0          0
# 2           17090.0          1
# 3           17909.0          0
# 4           18468.0          0
# ...             ...        ...
# 4883        26576.0          1
# 4884        21212.0          1
# 4885        31820.0          1
# 4886        20289.0          1
# 4887        24041.0          1
#
# [4888 rows x 19 columns]

# %%
data.corr()
# Out:
#                               Age  CityTier  DurationOfPitch  \
# Age                      1.000000 -0.012754        -0.006261
# CityTier                -0.012754  1.000000         0.019445
# DurationOfPitch         -0.006261  0.019445         1.000000
# NumberOfPersonVisited    0.017856 -0.001671         0.073163
# NumberOfFollowups        0.001682  0.024333         0.015515
# PreferredPropertyStar   -0.015932 -0.008479        -0.005442
# NumberOfTrips            0.174694 -0.028749         0.014153
# Passport                 0.032398  0.001793         0.033526
# PitchSatisfactionScore   0.017392 -0.042160        -0.002552
# OwnCar                   0.047356  0.003817        -0.002504
# NumberOfChildrenVisited  0.008486  0.000578         0.038115
# MonthlyIncome            0.461282  0.051790         0.003345
# ProdTaken               -0.143753  0.086852         0.076481
#
#                          NumberOfPersonVisited  NumberOfFollowups  \
# Age                                   0.017856           0.001682
# CityTier                             -0.001671           0.024333
# DurationOfPitch                       0.073163           0.015515
# NumberOfPersonVisited                 1.000000           0.324895
# NumberOfFollowups                     0.324895           1.000000
# PreferredPropertyStar                 0.030519          -0.026989
# NumberOfTrips                         0.190113           0.135103
# Passport                              0.011177           0.004411
# PitchSatisfactionScore               -0.019581           0.004405
# OwnCar                                0.010362           0.012186
# NumberOfChildrenVisited               0.606321           0.281583
# MonthlyIncome                         0.198449           0.175921
# ProdTaken                             0.009627           0.111560
#
#                          PreferredPropertyStar  NumberOfTrips  Passport  \
# Age                                  -0.015932       0.174694  0.032398
# CityTier                             -0.008479      -0.028749  0.001793
# DurationOfPitch                      -0.005442       0.014153  0.033526
# NumberOfPersonVisited                 0.030519       0.190113  0.011177
# NumberOfFollowups                    -0.026989       0.135103  0.004411
# PreferredPropertyStar                 1.000000       0.009432  0.001221
# NumberOfTrips                         0.009432       1.000000  0.012926
# Passport                              0.001221       0.012926  1.000000
# PitchSatisfactionScore               -0.024019      -0.004501  0.002926
# OwnCar                                0.013577      -0.012164 -0.022330
# NumberOfChildrenVisited               0.031362       0.161022  0.020244
# MonthlyIncome                        -0.000508       0.115210  0.003333
# ProdTaken                             0.098704       0.019709  0.260844
#
#                          PitchSatisfactionScore    OwnCar  \
# Age                                    0.017392  0.047356
# CityTier                              -0.042160  0.003817
# DurationOfPitch                       -0.002552 -0.002504
# NumberOfPersonVisited                 -0.019581  0.010362
# NumberOfFollowups                      0.004405  0.012186
# PreferredPropertyStar                 -0.024019  0.013577
# NumberOfTrips                         -0.004501 -0.012164
# Passport                               0.002926 -0.022330
# PitchSatisfactionScore                 1.000000  0.068850
# OwnCar                                 0.068850  1.000000
# NumberOfChildrenVisited                0.000251  0.025659
# MonthlyIncome                          0.028907  0.078458
# ProdTaken                              0.051394 -0.011508
#
#                          NumberOfChildrenVisited  MonthlyIncome  ProdTaken
# Age                                     0.008486       0.461282  -0.143753
# CityTier                                0.000578       0.051790   0.086852
# DurationOfPitch                         0.038115       0.003345   0.076481
# NumberOfPersonVisited                   0.606321       0.198449   0.009627
# NumberOfFollowups                       0.281583       0.175921   0.111560
# PreferredPropertyStar                   0.031362      -0.000508   0.098704
# NumberOfTrips                           0.161022       0.115210   0.019709
# Passport                                0.020244       0.003333   0.260844
# PitchSatisfactionScore                  0.000251       0.028907   0.051394
# OwnCar                                  0.025659       0.078458  -0.011508
# NumberOfChildrenVisited                 1.000000       0.189684   0.008009
# MonthlyIncome                           0.189684       1.000000  -0.126420
# ProdTaken                               0.008009      -0.126420   1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(),cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#        Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 0     41.0     Self Enquiry         3              6.0        Salaried
# 1     49.0  Company Invited         1             14.0        Salaried
# 2     37.0     Self Enquiry         1              8.0     Free Lancer
# 3     33.0  Company Invited         1              9.0        Salaried
# 4     36.0     Self Enquiry         1              8.0  Small Business
# ...    ...              ...       ...              ...             ...
# 4883  49.0     Self Enquiry         3              9.0  Small Business
# 4884  28.0  Company Invited         1             31.0        Salaried
# 4885  52.0     Self Enquiry         3             17.0        Salaried
# 4886  19.0     Self Enquiry         3             16.0  Small Business
# 4887  36.0     Self Enquiry         1             14.0        Salaried
#
#       Gender  NumberOfPersonVisited  NumberOfFollowups ProductPitched  \
# 0     Female                      3                3.0         Deluxe
# 1       Male                      3                4.0         Deluxe
# 2       Male                      3                4.0          Basic
# 3     Female                      2                3.0          Basic
# 4       Male                      2                3.0          Basic
# ...      ...                    ...                ...            ...
# 4883    Male                      3                5.0         Deluxe
# 4884    Male                      4                5.0          Basic
# 4885  Female                      4                4.0       Standard
# 4886    Male                      3                4.0          Basic
# 4887    Male                      4                4.0          Basic
#
#       PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 0                       3.0        Single            1.0         1
# 1                       4.0      Divorced            2.0         0
# 2                       3.0        Single            7.0         1
# 3                       3.0      Divorced            2.0         1
# 4                       4.0      Divorced            1.0         0
# ...                     ...           ...            ...       ...
# 4883                    4.0     Unmarried            2.0         1
# 4884                    3.0        Single            3.0         1
# 4885                    4.0       Married            7.0         0
# 4886                    3.0        Single            3.0         0
# 4887                    4.0     Unmarried            3.0         1
#
#       PitchSatisfactionScore  OwnCar  NumberOfChildrenVisited     Designation  \
# 0                          2       1                      0.0         Manager
# 1                          3       1                      2.0         Manager
# 2                          3       0                      0.0       Executive
# 3                          5       1                      1.0       Executive
# 4                          5       1                      0.0       Executive
# ...                      ...     ...                      ...             ...
# 4883                       1       1                      1.0         Manager
# 4884                       3       1                      2.0       Executive
# 4885                       1       1                      3.0  Senior Manager
# 4886                       5       0                      2.0       Executive
# 4887                       3       1                      2.0       Executive
#
#       MonthlyIncome  ProdTaken
# 0           20993.0          1
# 1           20130.0          0
# 2           17090.0          1
# 3           17909.0          0
# 4           18468.0          0
# ...             ...        ...
# 4883        26576.0          1
# 4884        21212.0          1
# 4885        31820.0          1
# 4886        20289.0          1
# 4887        24041.0          1
#
# [4888 rows x 19 columns]

# %%
catFeature = [feature for feature in data.columns if data[feature].dtype == 'O']
numFeature = [feature for feature in data.columns if data[feature].dtype != 'O']

# %%
def encodeTheData(data,colName1,colName2):
    data = pd.get_dummies(data, columns = [colName1[0],colName1[1],colName1[2],colName1[3]],drop_first=True)
    data[colName2[0]]=data[colName2[0]].replace({'Basic':1,'Standard':2,'Deluxe':3,'Super Deluxe':4,'King':5})
    data[colName2[1]]=data[colName2[1]].replace({'Executive':1, 'Manager':2, 'Senior Manager':3, 'AVP':4, 'VP':5})
    
    Enoded_Data = data
    
    return Enoded_Data

col1 = ['TypeofContact','Occupation','Gender','MaritalStatus']
col2 = ['ProductPitched','Designation']

Enoded_Data = encodeTheData(data,col1,col2)

# %%
Enoded_Data
# Out:
#        Age  CityTier  DurationOfPitch  NumberOfPersonVisited  \
# 0     41.0         3              6.0                      3
# 1     49.0         1             14.0                      3
# 2     37.0         1              8.0                      3
# 3     33.0         1              9.0                      2
# 4     36.0         1              8.0                      2
# ...    ...       ...              ...                    ...
# 4883  49.0         3              9.0                      3
# 4884  28.0         1             31.0                      4
# 4885  52.0         3             17.0                      4
# 4886  19.0         3             16.0                      3
# 4887  36.0         1             14.0                      4
#
#       NumberOfFollowups  ProductPitched  PreferredPropertyStar  NumberOfTrips  \
# 0                   3.0               3                    3.0            1.0
# 1                   4.0               3                    4.0            2.0
# 2                   4.0               1                    3.0            7.0
# 3                   3.0               1                    3.0            2.0
# 4                   3.0               1                    4.0            1.0
# ...                 ...             ...                    ...            ...
# 4883                5.0               3                    4.0            2.0
# 4884                5.0               1                    3.0            3.0
# 4885                4.0               2                    4.0            7.0
# 4886                4.0               1                    3.0            3.0
# 4887                4.0               1                    4.0            3.0
#
#       Passport  PitchSatisfactionScore  ...  ProdTaken  \
# 0            1                       2  ...          1
# 1            0                       3  ...          0
# 2            1                       3  ...          1
# 3            1                       5  ...          0
# 4            0                       5  ...          0
# ...        ...                     ...  ...        ...
# 4883         1                       1  ...          1
# 4884         1                       3  ...          1
# 4885         0                       1  ...          1
# 4886         0                       5  ...          1
# 4887         1                       3  ...          1
#
#       TypeofContact_Self Enquiry  Occupation_Large Business  \
# 0                              1                          0
# 1                              0                          0
# 2                              1                          0
# 3                              0                          0
# 4                              1                          0
# ...                          ...                        ...
# 4883                           1                          0
# 4884                           0                          0
# 4885                           1                          0
# 4886                           1                          0
# 4887                           1                          0
#
#       Occupation_Salaried  Occupation_Small Business  Gender_Female  \
# 0                       1                          0              1
# 1                       1                          0              0
# 2                       0                          0              0
# 3                       1                          0              1
# 4                       0                          1              0
# ...                   ...                        ...            ...
# 4883                    0                          1              0
# 4884                    1                          0              0
# 4885                    1                          0              1
# 4886                    0                          1              0
# 4887                    1                          0              0
#
#       Gender_Male  MaritalStatus_Married  MaritalStatus_Single  \
# 0               0                      0                     1
# 1               1                      0                     0
# 2               1                      0                     1
# 3               0                      0                     0
# 4               1                      0                     0
# ...           ...                    ...                   ...
# 4883            1                      0                     0
# 4884            1                      0                     1
# 4885            0                      1                     0
# 4886            1                      0                     1
# 4887            1                      0                     0
#
#       MaritalStatus_Unmarried
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# ...                       ...
# 4883                        1
# 4884                        0
# 4885                        0
# 4886                        0
# 4887                        1
#
# [4888 rows x 24 columns]

# %%
X = Enoded_Data.loc[:,['Age', 'CityTier', 'DurationOfPitch', 'NumberOfPersonVisited',
       'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
       'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
       'NumberOfChildrenVisited', 'Designation', 'MonthlyIncome',
       'TypeofContact_Self Enquiry', 'Occupation_Large Business',
       'Occupation_Salaried', 'Occupation_Small Business', 'Gender_Female',
       'Gender_Male', 'MaritalStatus_Married', 'MaritalStatus_Single',
       'MaritalStatus_Unmarried']]
X
# Out:
#        Age  CityTier  DurationOfPitch  NumberOfPersonVisited  \
# 0     41.0         3              6.0                      3
# 1     49.0         1             14.0                      3
# 2     37.0         1              8.0                      3
# 3     33.0         1              9.0                      2
# 4     36.0         1              8.0                      2
# ...    ...       ...              ...                    ...
# 4883  49.0         3              9.0                      3
# 4884  28.0         1             31.0                      4
# 4885  52.0         3             17.0                      4
# 4886  19.0         3             16.0                      3
# 4887  36.0         1             14.0                      4
#
#       NumberOfFollowups  ProductPitched  PreferredPropertyStar  NumberOfTrips  \
# 0                   3.0               3                    3.0            1.0
# 1                   4.0               3                    4.0            2.0
# 2                   4.0               1                    3.0            7.0
# 3                   3.0               1                    3.0            2.0
# 4                   3.0               1                    4.0            1.0
# ...                 ...             ...                    ...            ...
# 4883                5.0               3                    4.0            2.0
# 4884                5.0               1                    3.0            3.0
# 4885                4.0               2                    4.0            7.0
# 4886                4.0               1                    3.0            3.0
# 4887                4.0               1                    4.0            3.0
#
#       Passport  PitchSatisfactionScore  ...  MonthlyIncome  \
# 0            1                       2  ...        20993.0
# 1            0                       3  ...        20130.0
# 2            1                       3  ...        17090.0
# 3            1                       5  ...        17909.0
# 4            0                       5  ...        18468.0
# ...        ...                     ...  ...            ...
# 4883         1                       1  ...        26576.0
# 4884         1                       3  ...        21212.0
# 4885         0                       1  ...        31820.0
# 4886         0                       5  ...        20289.0
# 4887         1                       3  ...        24041.0
#
#       TypeofContact_Self Enquiry  Occupation_Large Business  \
# 0                              1                          0
# 1                              0                          0
# 2                              1                          0
# 3                              0                          0
# 4                              1                          0
# ...                          ...                        ...
# 4883                           1                          0
# 4884                           0                          0
# 4885                           1                          0
# 4886                           1                          0
# 4887                           1                          0
#
#       Occupation_Salaried  Occupation_Small Business  Gender_Female  \
# 0                       1                          0              1
# 1                       1                          0              0
# 2                       0                          0              0
# 3                       1                          0              1
# 4                       0                          1              0
# ...                   ...                        ...            ...
# 4883                    0                          1              0
# 4884                    1                          0              0
# 4885                    1                          0              1
# 4886                    0                          1              0
# 4887                    1                          0              0
#
#       Gender_Male  MaritalStatus_Married  MaritalStatus_Single  \
# 0               0                      0                     1
# 1               1                      0                     0
# 2               1                      0                     1
# 3               0                      0                     0
# 4               1                      0                     0
# ...           ...                    ...                   ...
# 4883            1                      0                     0
# 4884            1                      0                     1
# 4885            0                      1                     0
# 4886            1                      0                     1
# 4887            1                      0                     0
#
#       MaritalStatus_Unmarried
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# ...                       ...
# 4883                        1
# 4884                        0
# 4885                        0
# 4886                        0
# 4887                        1
#
# [4888 rows x 23 columns]

# %%
y = Enoded_Data.loc[:,['ProdTaken']]
y
# Out:
#       ProdTaken
# 0             1
# 1             0
# 2             1
# 3             0
# 4             0
# ...         ...
# 4883          1
# 4884          1
# 4885          1
# 4886          1
# 4887          1
#
# [4888 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_train
# Out:
# array([[-0.70893617, -0.72170819, -0.6533179 , ..., -0.96514602,
#         -0.47548602,  2.46797672],
#        [-0.15440856, -0.72170819, -0.16552494, ...,  1.03611264,
#         -0.47548602, -0.40519021],
#        [-0.04350304, -0.72170819, -0.28747318, ..., -0.96514602,
#         -0.47548602, -0.40519021],
#        ...,
#        [ 0.06740248,  1.45499459,  1.54175041, ..., -0.96514602,
#         -0.47548602, -0.40519021],
#        [-1.04165273,  1.45499459,  1.78564689, ...,  1.03611264,
#         -0.47548602, -0.40519021],
#        [-1.70708586, -0.72170819, -0.77526614, ..., -0.96514602,
#         -0.47548602, -0.40519021]])

# %%
from sklearn.svm import SVC
SvcModel  = SVC()
from sklearn.model_selection import GridSearchCV


SVCPara = {'C':[0.1,1,100],
           'kernel':['poly','sigmoid'],
           'degree':[1,2,3,4,5,6]
          }


X_test = scaler.transform(X_test)
X_test
# Out:
# array([[-0.59803065,  1.45499459, -0.28747318, ...,  1.03611264,
#         -0.47548602, -0.40519021],
#        [ 0.95464665,  0.3666432 , -0.53136966, ...,  1.03611264,
#         -0.47548602, -0.40519021],
#        [-0.04350304,  1.45499459,  0.81006097, ...,  1.03611264,
#         -0.47548602, -0.40519021],
#        ...,
#        [-0.15440856,  1.45499459, -0.28747318, ..., -0.96514602,
#          2.10311125, -0.40519021],
#        [-0.3762196 , -0.72170819,  1.54175041, ...,  1.03611264,
#         -0.47548602, -0.40519021],
#        [-0.81984169, -0.72170819, -0.0435767 , ..., -0.96514602,
#          2.10311125, -0.40519021]])

# %%
grid = GridSearchCV(SvcModel,SVCPara,cv=3)
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 100], 'degree': [1, 2, 3, 4, 5, 6],
#                          'kernel': ['poly', 'sigmoid']})

# %%
grid.score(X_train, y_train)
# Out:
# 0.9997272231314784

# %%
y_predict = grid.predict(X_test)
y_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_predict)
# Out:
# 0.9222585924713584

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

param={'Svc' : {
        'C':[0.1,1,100],
        'kernel':['rbf','poly','sigmoid'],
        'degree':[1,2,3,4,5,6]
      },
      "Logistic Regression" : {
          'penalty': ['l1', 'l2', 'elasticnet'],
                'C': np.logspace(-4, 4, 20),
                'solver': ['lbfgs', 'newton-cg', 'liblinear', 'sag', 'saga'],
                'max_iter': [100, 1000, 2500, 5000]
               }
      
      }

models = {
    "Svc": SVC(),
    "Logistic Regression" : LogisticRegression()
}

    
report = {}

for i in range(len(list(models))):
    model = list(models.values())[i]
    print(model)

    para = param[list(models.keys())[i]]

    gs = GridSearchCV(model, para, cv=3)
    gs.fit(X_train, y_train)

    model.set_params(**gs.best_params_)
    model.fit(X_train, y_train)
    X_train_prediction = model.predict(X_train)
    training_data_accuracy = accuracy_score(y_train, X_train_prediction)
    print("training_data_accuracy = ",training_data_accuracy)
    X_test_prediction = model.predict(X_test)
    test_data_accuracy = accuracy_score(y_test, X_test_prediction)
    print("test_data_accuracy = ",test_data_accuracy)
    precision_train = precision_score(y_train, X_train_prediction)
    print('Training data Precision = ', precision_train)
    precision_test = precision_score(y_test, X_test_prediction)
    print('Test data Precision = ', precision_test)
    recall_train = recall_score(y_train, X_train_prediction)
    print('Training data Recall = ', recall_train)
    recall_test = recall_score(y_test, X_test_prediction)
    print('Test data Recall = ', recall_test)
    report[list(models.keys())[i]] = precision_test

    
print(report)
# Out:
# SVC()
# training_data_accuracy =  1.0
# test_data_accuracy =  0.9378068739770867
# Training data Precision =  1.0
# Test data Precision =  0.8769230769230769
# Training data Recall =  1.0
# Test data Recall =  0.7668161434977578
# LogisticRegression()
# training_data_accuracy =  0.8404255319148937
# test_data_accuracy =  0.8469721767594108
# Training data Precision =  0.724
# Test data Precision =  0.6875
# Training data Recall =  0.25968436154949787
# Test data Recall =  0.29596412556053814
# {'Svc': 0.8769230769230769, 'Logistic Regression': 0.6875}
