# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("tourismData.xlsx",'Tourism')

# %%
df.shape
# Out:
# (4888, 20)

# %%
df.head(6)
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
# 5      200005          0  32.0  Company Invited         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisited  NumberOfFollowups  \
# 0        Salaried  Female                      3                3.0
# 1        Salaried    Male                      3                4.0
# 2     Free Lancer    Male                      3                4.0
# 3        Salaried  Female                      2                3.0
# 4  Small Business    Male                      2                3.0
# ...

# %%
df.dtypes
# Out:
# CustomerID                   int64
# ProdTaken                    int64
# Age                        float64
# TypeofContact               object
# CityTier                     int64
# DurationOfPitch            float64
# Occupation                  object
# Gender                      object
# NumberOfPersonVisited        int64
# NumberOfFollowups          float64
# ProductPitched              object
# PreferredPropertyStar      float64
# MaritalStatus               object
# NumberOfTrips              float64
# Passport                     int64
# PitchSatisfactionScore       int64
# OwnCar                       int64
# NumberOfChildrenVisited    float64
# Designation                 object
# MonthlyIncome              float64
# dtype: object

# %%
df_cat = df[['TypeofContact', 'Occupation', 'Gender', 'ProductPitched', 'MaritalStatus', 'Designation']]

# %%
print("TypeContact unique LabelEncoded:", df_cat.TypeofContact.unique())
print("Occupation unique OneHotEncoded:", df_cat.Occupation.unique())
print("Gender unique LabelEncoded:", df_cat.Gender.unique())
print("ProductPitched unique OneHotEncoded:", df_cat.ProductPitched.unique())
print("MaritalStatus unique OneHotEncoded:", df_cat.MaritalStatus.unique())
print("Designation unique OneHotEncoded:", df_cat.Designation.unique())
# Out:
# TypeContact unique LabelEncoded: ['Self Enquiry' 'Company Invited' nan]
# Occupation unique OneHotEncoded: ['Salaried' 'Free Lancer' 'Small Business' 'Large Business']
# Gender unique LabelEncoded: ['Female' 'Male' 'Fe Male']
# ProductPitched unique OneHotEncoded: ['Deluxe' 'Basic' 'Standard' 'Super Deluxe' 'King']
# MaritalStatus unique OneHotEncoded: ['Single' 'Divorced' 'Married' 'Unmarried']
# Designation unique OneHotEncoded: ['Manager' 'Executive' 'Senior Manager' 'AVP' 'VP']

# %%
df_num = df[['ProdTaken', 'Age', 'CityTier', 'DurationOfPitch', 'NumberOfPersonVisited', 'NumberOfFollowups', 'PreferredPropertyStar', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar', 'NumberOfChildrenVisited', 'MonthlyIncome']]

# %%
print("ProdTaken unique:", df_num.ProdTaken.unique())
print("Age unique:", df_num.Age.unique())
print("CityTier unique:", df_num.CityTier.unique())
print("DurationOfPitch unique:", df_num.DurationOfPitch.unique())
print("NumberOfPersonVisited unique:", df_num.NumberOfPersonVisited.unique())
print("NumberOfFollowups unique:", df_num.NumberOfFollowups.unique())
print("PreferredPropertyStar unique:", df_num.PreferredPropertyStar.unique())
print("NumberOfTrips unique:", df_num.NumberOfTrips.unique())
print("Passport unique:", df_num.Passport.unique())
print("PitchSatisfactionScore unique:", df_num.PitchSatisfactionScore.unique())
print("OwnCar unique:", df_num.OwnCar.unique())
print("NumberOfChildrenVisited unique:", df_num.NumberOfChildrenVisited.unique())
# Out:
# ProdTaken unique: [1 0]
# Age unique: [41. 49. 37. 33. nan 32. 59. 30. 38. 36. 35. 31. 34. 28. 29. 22. 53. 21.
#  42. 44. 46. 39. 24. 43. 50. 27. 26. 48. 55. 45. 56. 23. 51. 40. 54. 58.
#  20. 25. 19. 57. 52. 47. 18. 60. 61.]
# CityTier unique: [3 1 2]
# DurationOfPitch unique: [  6.  14.   8.   9.  30.  29.  33.  22.  21.  32.  25.  27.  11.  17.
#   15.  13.  12.  16.  10.  31.  18.  nan  24.  35.  28.  20.  26.  34.
#   23.   5.  19. 126.   7.  36. 127.]
# NumberOfPersonVisited unique: [3 2 1 4 5]
# NumberOfFollowups unique: [ 3.  4.  2.  5. nan  1.  6.]
# PreferredPropertyStar unique: [ 3.  4.  5. nan]
# NumberOfTrips unique: [ 1.  2.  7.  5.  6.  3.  4. 19. 21.  8. nan 20. 22.]
# Passport unique: [1 0]
# PitchSatisfactionScore unique: [2 3 5 4 1]
# OwnCar unique: [1 0]
# NumberOfChildrenVisited unique: [ 0.  2.  1. nan  3.]

# %%
df.isna().sum()
# Out:
# CustomerID                   0
# ProdTaken                    0
# Age                        226
# TypeofContact               25
# CityTier                     0
# DurationOfPitch            251
# Occupation                   0
# Gender                       0
# NumberOfPersonVisited        0
# NumberOfFollowups           45
# ProductPitched               0
# PreferredPropertyStar       26
# MaritalStatus                0
# NumberOfTrips              140
# Passport                     0
# PitchSatisfactionScore       0
# OwnCar                       0
# NumberOfChildrenVisited     66
# Designation                  0
# MonthlyIncome              233
# dtype: int64

# %%
df.TypeofContact.mode()
# Out:
# 0    Self Enquiry
# dtype: object

# %%
df['Gender'].replace('Fe Male','Female',inplace=True)  
df['Gender'].unique()
df['MaritalStatus'].replace('Single','Unmarried',inplace=True)  
df['MaritalStatus'].unique()
# Out:
# array(['Unmarried', 'Divorced', 'Married'], dtype=object)

# %%
df['Age'].fillna(df['Age'].median(),inplace=True)
df['TypeofContact'].fillna(df['TypeofContact'].mode()[0],inplace=True)
df['DurationOfPitch'].fillna(df['DurationOfPitch'].median(),inplace=True)
df['NumberOfFollowups'].fillna(df['NumberOfFollowups'].median(),inplace=True)
df['PreferredPropertyStar'].fillna(df['PreferredPropertyStar'].median(),inplace=True)
df['NumberOfTrips'].fillna(df['NumberOfTrips'].median(),inplace=True)
df['NumberOfChildrenVisited'].fillna(df['NumberOfChildrenVisited'].median(),inplace=True)
df['MonthlyIncome'].fillna(df['MonthlyIncome'].median(),inplace=True)

df.isna().sum()
# Out:
# CustomerID                 0
# ProdTaken                  0
# Age                        0
# TypeofContact              0
# CityTier                   0
# DurationOfPitch            0
# Occupation                 0
# Gender                     0
# NumberOfPersonVisited      0
# NumberOfFollowups          0
# ProductPitched             0
# PreferredPropertyStar      0
# MaritalStatus              0
# NumberOfTrips              0
# Passport                   0
# PitchSatisfactionScore     0
# OwnCar                     0
# NumberOfChildrenVisited    0
# Designation                0
# MonthlyIncome              0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (4888, 20)

# %%
df = df[['Age', 'TypeofContact', 'CityTier',
       'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisited',
       'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
       'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
       'OwnCar', 'NumberOfChildrenVisited', 'Designation', 'MonthlyIncome','ProdTaken']]

df
# Out:
#        Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 0     41.0     Self Enquiry         3              6.0        Salaried
# 1     49.0  Company Invited         1             14.0        Salaried
# 2     37.0     Self Enquiry         1              8.0     Free Lancer
# 3     33.0  Company Invited         1              9.0        Salaried
# 4     36.0     Self Enquiry         1              8.0  Small Business
# ...    ...              ...       ...              ...             ...
# 4883  49.0     Self Enquiry         3              9.0  Small Business
# 4884  28.0  Company Invited         1             31.0        Salaried
# 4885  52.0     Self Enquiry         3             17.0        Salaried
# 4886  19.0     Self Enquiry         3             16.0  Small Business
# 4887  36.0     Self Enquiry         1             14.0        Salaried
#
#       Gender  NumberOfPersonVisited  NumberOfFollowups ProductPitched  \
# ...

# %%
plt.figure(figsize=(15,10))
df.corr()
sns.heatmap(df.corr(),cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(df['OwnCar'],hue=df['ProdTaken'])
# Out:
# <AxesSubplot:xlabel='OwnCar', ylabel='count'>

# %%
CatFr = [feature for feature in df.columns if df[feature].dtype == 'O']
NumFr = [feature for feature in df.columns if df[feature].dtype != 'O']

# %%
print("Cat feature :", len(CatFr))
print("Num feature :", len(NumFr))
# Out:
# Cat feature : 6
# Num feature : 13

# %%
smallValueFeature = ['TypeofContact','Occupation','Gender','ProductPitched','MaritalStatus','Designation',
                     'CityTier','NumberOfPersonVisited','NumberOfFollowups','PreferredPropertyStar',
                     'Passport','PitchSatisfactionScore','OwnCar','NumberOfChildrenVisited']

longValueFeature = ['Age','DurationOfPitch','NumberOfTrips','MonthlyIncome']

# %%
data=df[df.ProdTaken==1]

plt.figure(figsize=(15,22))
for i in enumerate(smallValueFeature):
    plt.subplot(5,3,i[0]+1)
    sns.countplot(data=data,x = data['ProdTaken'],hue=data[i[1]])

# %% [markdown]
# #Obvservations
# #
# 1) Self Enquiry customer is morelikely to buy a product than Company Invited
# #
# 2) Saliried and Small business owners are more likely to buy a product
# #
# 3) Male are frequent traveller than Female
# #
# 4) People are opting Basic product than premium
# #
# 5) Unmarried people are more likey to travel
# 6) Exectives have bought more pakcage than anyone else
# 7) Tier One City are more frequent Traveller
# 8) Family of 3 are more frequest traveller
# 9) Folloup 4 has more conversions
# 10) Three start is most popular Hotel
# 11) passort holders have bough more packages
# 12) car Owners have more chances of travel.
# 13) Family with one child have bough more product
# ###

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=df[df['ProdTaken']==1],x='Age',kde=True,hue=df['Gender'],multiple='dodge',shrink=0.9)
plt.title("Age",fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Age')

# %%
plt.figure(figsize=(15,5))

sns.histplot(data=df[df['ProdTaken']==1],x='Age',hue=df['Gender'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(15,5))

sns.countplot(data=df[df['ProdTaken']==1],x='Designation')
# Out:
# <AxesSubplot:xlabel='Designation', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x=df['MonthlyIncome'],width=.7)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x=df['NumberOfTrips'],width=.7)
# Out:
# <AxesSubplot:xlabel='NumberOfTrips'>

# %%
plt.figure(figsize=(20,5))
sns.boxplot(y=df['MaritalStatus'],x=df['MonthlyIncome'],width=.7)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='MaritalStatus'>

# %%
plt.figure(figsize=(10,10))
sns.violinplot(y=df['MonthlyIncome'],x=df['MaritalStatus'],hue=df['Gender'])
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='MonthlyIncome'>

# %%
sns.stripplot(y=df['MonthlyIncome'],x=df['Occupation'],jitter=0.3,linewidth=0.5,hue=df['Gender'],dodge=True)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='MonthlyIncome'>

# %%
df['MaritalStatus'].value_counts()
# Out:
# Married      2340
# Unmarried    1598
# Divorced      950
# Name: MaritalStatus, dtype: int64

# %%
df.head(3).T
# Out:
#                                     0                1             2
# Age                                41               49            37
# TypeofContact            Self Enquiry  Company Invited  Self Enquiry
# CityTier                            3                1             1
# DurationOfPitch                     6               14             8
# Occupation                   Salaried         Salaried   Free Lancer
# Gender                         Female             Male          Male
# NumberOfPersonVisited               3                3             3
# NumberOfFollowups                   3                4             4
# ProductPitched                 Deluxe           Deluxe         Basic
# PreferredPropertyStar               3                4             3
# MaritalStatus               Unmarried         Divorced     Unmarried
# NumberOfTrips                       1                2             7
# Passport                            1                0             1
# ...

# %%
X= df.iloc[:,:-1]
X
y = df.loc[:,'ProdTaken']
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 4883    1
# 4884    1
# 4885    1
# 4886    1
# 4887    1
# Name: ProdTaken, Length: 4888, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
#X_train.to_csv("X_train1.csv")
#X_test.to_csv("X_test2.csv")
'''
print("TypeContact unique LabelEncoded:", df_cat.TypeofContact.unique())
print("Occupation unique OneHotEncoded:", df_cat.Occupation.unique())
print("Gender unique LabelEncoded:", df_cat.Gender.unique())
print("ProductPitched unique OneHotEncoded:", df_cat.ProductPitched.unique())
print("MaritalStatus unique OneHotEncoded:", df_cat.MaritalStatus.unique())
print("Designation unique OneHotEncoded:", df_cat.Designation.unique())
'''
# Out:
# '\nprint("TypeContact unique LabelEncoded:", df_cat.TypeofContact.unique())\nprint("Occupation unique OneHotEncoded:", df_cat.Occupation.unique())\nprint("Gender unique LabelEncoded:", df_cat.Gender.unique())\nprint("ProductPitched unique OneHotEncoded:", df_cat.ProductPitched.unique())\nprint("MaritalStatus unique OneHotEncoded:", df_cat.MaritalStatus.unique())\nprint("Designation unique OneHotEncoded:", df_cat.Designation.unique())\n'

# %%
X_train = pd.get_dummies(X_train, columns = ['TypeofContact','Occupation','Gender','ProductPitched','MaritalStatus','Designation'],drop_first=True)

# %%
X_test = pd.get_dummies(X_test, columns = ['TypeofContact','Occupation','Gender','ProductPitched', 'MaritalStatus'],drop_first=True)

X_test
# Out:
#        Age  CityTier  DurationOfPitch  NumberOfPersonVisited  \
# 144   32.0         3             13.0                      2
# 79    46.0         2             11.0                      3
# 2098  37.0         3             22.0                      3
# 4738  43.0         1             36.0                      3
# 2858  25.0         3              7.0                      4
# ...    ...       ...              ...                    ...
# 2908  38.0         1              7.0                      3
# 2059  29.0         1              6.0                      2
# 4872  35.0         1             24.0                      3
# 843   26.0         1             13.0                      2
# 2572  23.0         1              9.0                      4
#
#       NumberOfFollowups  PreferredPropertyStar  NumberOfTrips  Passport  \
# 144                 5.0                    3.0            1.0         0
# 79                  4.0                    4.0            1.0         1
# ...
