# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("tourismData.xlsx",'Tourism')

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisited  NumberOfFollowups  \
# 0        Salaried  Female                      3                3.0
# 1        Salaried    Male                      3                4.0
# 2     Free Lancer    Male                      3                4.0
# 3        Salaried  Female                      2                3.0
# 4  Small Business    Male                      2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0         Deluxe                    3.0        Single            1.0
# 1         Deluxe                    4.0      Divorced            2.0
# 2          Basic                    3.0        Single            7.0
# 3          Basic                    3.0      Divorced            2.0
# 4          Basic                    4.0      Divorced            1.0
#
#    Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisited  \
# 0         1                       2       1                      0.0
# 1         0                       3       1                      2.0
# 2         1                       3       0                      0.0
# 3         1                       5       1                      1.0
# 4         0                       5       1                      0.0
#
#   Designation  MonthlyIncome
# 0     Manager        20993.0
# 1     Manager        20130.0
# 2   Executive        17090.0
# 3   Executive        17909.0
# 4   Executive        18468.0

# %%
df.isnull().sum()
# Out:
# CustomerID                   0
# ProdTaken                    0
# Age                        226
# TypeofContact               25
# CityTier                     0
# DurationOfPitch            251
# Occupation                   0
# Gender                       0
# NumberOfPersonVisited        0
# NumberOfFollowups           45
# ProductPitched               0
# PreferredPropertyStar       26
# MaritalStatus                0
# NumberOfTrips              140
# Passport                     0
# PitchSatisfactionScore       0
# OwnCar                       0
# NumberOfChildrenVisited     66
# Designation                  0
# MonthlyIncome              233
# dtype: int64

# %%
df[df.Age.notna()]
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 5         200005          0  32.0  Company Invited         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisited  NumberOfFollowups  \
# 0           Salaried  Female                      3                3.0
# 1           Salaried    Male                      3                4.0
# 2        Free Lancer    Male                      3                4.0
# 3           Salaried  Female                      2                3.0
# 5           Salaried    Male                      3                3.0
# ...              ...     ...                    ...                ...
# 4883  Small Business    Male                      3                5.0
# 4884        Salaried    Male                      4                5.0
# 4885        Salaried  Female                      4                4.0
# 4886  Small Business    Male                      3                4.0
# 4887        Salaried    Male                      4                4.0
#
#      ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0            Deluxe                    3.0        Single            1.0
# 1            Deluxe                    4.0      Divorced            2.0
# 2             Basic                    3.0        Single            7.0
# 3             Basic                    3.0      Divorced            2.0
# 5             Basic                    3.0        Single            1.0
# ...             ...                    ...           ...            ...
# 4883         Deluxe                    4.0     Unmarried            2.0
# 4884          Basic                    3.0        Single            3.0
# 4885       Standard                    4.0       Married            7.0
# 4886          Basic                    3.0        Single            3.0
# 4887          Basic                    4.0     Unmarried            3.0
#
#       Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisited  \
# 0            1                       2       1                      0.0
# 1            0                       3       1                      2.0
# 2            1                       3       0                      0.0
# 3            1                       5       1                      1.0
# 5            0                       5       1                      1.0
# ...        ...                     ...     ...                      ...
# 4883         1                       1       1                      1.0
# 4884         1                       3       1                      2.0
# 4885         0                       1       1                      3.0
# 4886         0                       5       0                      2.0
# 4887         1                       3       1                      2.0
#
#          Designation  MonthlyIncome
# 0            Manager        20993.0
# 1            Manager        20130.0
# 2          Executive        17090.0
# 3          Executive        17909.0
# 5          Executive        18068.0
# ...              ...            ...
# 4883         Manager        26576.0
# 4884       Executive        21212.0
# 4885  Senior Manager        31820.0
# 4886       Executive        20289.0
# 4887       Executive        24041.0
#
# [4662 rows x 20 columns]

# %%
abc =df['Age'].isnull()

# %%
df.loc[(df['Age']==df['Age'].isnull())]
# Out:
# Empty DataFrame
# Columns: [CustomerID, ProdTaken, Age, TypeofContact, CityTier, DurationOfPitch, Occupation, Gender, NumberOfPersonVisited, NumberOfFollowups, ProductPitched, PreferredPropertyStar, MaritalStatus, NumberOfTrips, Passport, PitchSatisfactionScore, OwnCar, NumberOfChildrenVisited, Designation, MonthlyIncome]
# Index: []

# %%
df[['Age','TypeofContact']]
# Out:
#        Age    TypeofContact
# 0     41.0     Self Enquiry
# 1     49.0  Company Invited
# 2     37.0     Self Enquiry
# 3     33.0  Company Invited
# 4      NaN     Self Enquiry
# ...    ...              ...
# 4883  49.0     Self Enquiry
# 4884  28.0  Company Invited
# 4885  52.0     Self Enquiry
# 4886  19.0     Self Enquiry
# 4887  36.0     Self Enquiry
#
# [4888 rows x 2 columns]

# %%
df['Gender'].replace('Fe Male','Female',inplace=True)  
df['Gender'].unique()
df['MaritalStatus'].replace('Single','Unmarried',inplace=True)  
df['MaritalStatus'].unique()
# Out:
# array(['Unmarried', 'Divorced', 'Married'], dtype=object)

# %%
age = (df['Age'].isnull())
contact = (df['TypeofContact'].isnull())
DP = (df['DurationOfPitch'].isnull())
NOF = (df['NumberOfFollowups'].isnull())

PPStar = (df['PreferredPropertyStar'].isnull())

NOfTrips = (df['NumberOfTrips'].isnull())
NCVisited = (df['NumberOfChildrenVisited'].isnull())
MIncome = (df['MonthlyIncome'].isnull())

filtered_df = df[age|contact|DP|NOF|PPStar|NOfTrips|NCVisited|MIncome]
filtered_df.to_csv('abc.csv')
filtered_df
filtered_df = df[df.isnull()]
filtered_df.to_csv('abc.csv')

# %%
df['Age'].fillna(df['Age'].median(),inplace=True)
df['TypeofContact'].fillna(df['TypeofContact'].mode()[0],inplace=True)
df['DurationOfPitch'].fillna(df['DurationOfPitch'].median(),inplace=True)
df['NumberOfFollowups'].fillna(df['NumberOfFollowups'].median(),inplace=True)
df['PreferredPropertyStar'].fillna(df['PreferredPropertyStar'].median(),inplace=True)
df['NumberOfTrips'].fillna(df['NumberOfTrips'].median(),inplace=True)
df['NumberOfChildrenVisited'].fillna(df['NumberOfChildrenVisited'].median(),inplace=True)
df['MonthlyIncome'].fillna(df['MonthlyIncome'].median(),inplace=True)



df.isna().sum()
# Out:
# CustomerID                 0
# ProdTaken                  0
# Age                        0
# TypeofContact              0
# CityTier                   0
# DurationOfPitch            0
# Occupation                 0
# Gender                     0
# NumberOfPersonVisited      0
# NumberOfFollowups          0
# ProductPitched             0
# PreferredPropertyStar      0
# MaritalStatus              0
# NumberOfTrips              0
# Passport                   0
# PitchSatisfactionScore     0
# OwnCar                     0
# NumberOfChildrenVisited    0
# Designation                0
# MonthlyIncome              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisited',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisited', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df = df[['Age', 'TypeofContact', 'CityTier',
       'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisited',
       'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
       'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
       'OwnCar', 'NumberOfChildrenVisited', 'Designation', 'MonthlyIncome','ProdTaken']]

df
# Out:
#        Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 0     41.0     Self Enquiry         3              6.0        Salaried
# 1     49.0  Company Invited         1             14.0        Salaried
# 2     37.0     Self Enquiry         1              8.0     Free Lancer
# 3     33.0  Company Invited         1              9.0        Salaried
# 4     36.0     Self Enquiry         1              8.0  Small Business
# ...    ...              ...       ...              ...             ...
# 4883  49.0     Self Enquiry         3              9.0  Small Business
# 4884  28.0  Company Invited         1             31.0        Salaried
# 4885  52.0     Self Enquiry         3             17.0        Salaried
# 4886  19.0     Self Enquiry         3             16.0  Small Business
# 4887  36.0     Self Enquiry         1             14.0        Salaried
#
#       Gender  NumberOfPersonVisited  NumberOfFollowups ProductPitched  \
# 0     Female                      3                3.0         Deluxe
# 1       Male                      3                4.0         Deluxe
# 2       Male                      3                4.0          Basic
# 3     Female                      2                3.0          Basic
# 4       Male                      2                3.0          Basic
# ...      ...                    ...                ...            ...
# 4883    Male                      3                5.0         Deluxe
# 4884    Male                      4                5.0          Basic
# 4885  Female                      4                4.0       Standard
# 4886    Male                      3                4.0          Basic
# 4887    Male                      4                4.0          Basic
#
#       PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 0                       3.0     Unmarried            1.0         1
# 1                       4.0      Divorced            2.0         0
# 2                       3.0     Unmarried            7.0         1
# 3                       3.0      Divorced            2.0         1
# 4                       4.0      Divorced            1.0         0
# ...                     ...           ...            ...       ...
# 4883                    4.0     Unmarried            2.0         1
# 4884                    3.0     Unmarried            3.0         1
# 4885                    4.0       Married            7.0         0
# 4886                    3.0     Unmarried            3.0         0
# 4887                    4.0     Unmarried            3.0         1
#
#       PitchSatisfactionScore  OwnCar  NumberOfChildrenVisited     Designation  \
# 0                          2       1                      0.0         Manager
# 1                          3       1                      2.0         Manager
# 2                          3       0                      0.0       Executive
# 3                          5       1                      1.0       Executive
# 4                          5       1                      0.0       Executive
# ...                      ...     ...                      ...             ...
# 4883                       1       1                      1.0         Manager
# 4884                       3       1                      2.0       Executive
# 4885                       1       1                      3.0  Senior Manager
# 4886                       5       0                      2.0       Executive
# 4887                       3       1                      2.0       Executive
#
#       MonthlyIncome  ProdTaken
# 0           20993.0          1
# 1           20130.0          0
# 2           17090.0          1
# 3           17909.0          0
# 4           18468.0          0
# ...             ...        ...
# 4883        26576.0          1
# 4884        21212.0          1
# 4885        31820.0          1
# 4886        20289.0          1
# 4887        24041.0          1
#
# [4888 rows x 19 columns]

# %%
plt.figure(figsize=(15,10))
df.corr()
sns.heatmap(df.corr(),cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(df['OwnCar'],hue=df['ProdTaken'])
# Out:
# <AxesSubplot:xlabel='OwnCar', ylabel='count'>

# %%
for i in df.columns:
    print(i)
    print(df[i].value_counts())
    print()
# Out:
# Age
# 36.0    457
# 35.0    237
# 34.0    211
# 31.0    203
# 30.0    199
# 32.0    197
# 33.0    189
# 37.0    185
# 29.0    178
# 38.0    176
# 41.0    155
# 39.0    150
# 28.0    147
# 40.0    146
# 42.0    142
# 27.0    138
# 43.0    130
# 46.0    121
# 45.0    116
# 26.0    106
# 44.0    105
# 51.0     90
# 47.0     88
# 50.0     86
# 25.0     74
# 52.0     68
# 53.0     66
# 48.0     65
# 49.0     65
# 55.0     64
# 54.0     61
# 56.0     58
# 24.0     56
# 22.0     46
# 23.0     46
# 59.0     44
# 21.0     41
# 20.0     38
# 19.0     32
# 58.0     31
# 60.0     29
# 57.0     29
# 18.0     14
# 61.0      9
# Name: Age, dtype: int64
#
# TypeofContact
# Self Enquiry       3469
# Company Invited    1419
# Name: TypeofContact, dtype: int64
#
# CityTier
# 1    3190
# 3    1500
# 2     198
# Name: CityTier, dtype: int64
#
# DurationOfPitch
# 9.0      483
# 13.0     474
# 7.0      342
# 8.0      333
# 6.0      307
# 16.0     274
# 15.0     269
# 14.0     253
# 10.0     244
# 11.0     205
# 12.0     195
# 17.0     172
# 30.0      95
# 22.0      89
# 31.0      83
# 23.0      79
# 18.0      75
# 32.0      74
# 29.0      74
# 21.0      73
# 25.0      73
# 27.0      72
# 26.0      72
# 24.0      70
# 35.0      66
# 20.0      65
# 28.0      61
# 33.0      57
# 19.0      57
# 34.0      50
# 36.0      44
# 5.0        6
# 126.0      1
# 127.0      1
# Name: DurationOfPitch, dtype: int64
#
# Occupation
# Salaried          2368
# Small Business    2084
# Large Business     434
# Free Lancer          2
# Name: Occupation, dtype: int64
#
# Gender
# Male      2916
# Female    1972
# Name: Gender, dtype: int64
#
# NumberOfPersonVisited
# 3    2402
# 2    1418
# 4    1026
# 1      39
# 5       3
# Name: NumberOfPersonVisited, dtype: int64
#
# NumberOfFollowups
# 4.0    2113
# 3.0    1466
# 5.0     768
# 2.0     229
# 1.0     176
# 6.0     136
# Name: NumberOfFollowups, dtype: int64
#
# ProductPitched
# Basic           1842
# Deluxe          1732
# Standard         742
# Super Deluxe     342
# King             230
# Name: ProductPitched, dtype: int64
#
# PreferredPropertyStar
# 3.0    3019
# 5.0     956
# 4.0     913
# Name: PreferredPropertyStar, dtype: int64
#
# MaritalStatus
# Married      2340
# Unmarried    1598
# Divorced      950
# Name: MaritalStatus, dtype: int64
#
# NumberOfTrips
# 2.0     1464
# 3.0     1219
# 1.0      620
# 4.0      478
# 5.0      458
# 6.0      322
# 7.0      218
# 8.0      105
# 21.0       1
# 19.0       1
# 22.0       1
# 20.0       1
# Name: NumberOfTrips, dtype: int64
#
# Passport
# 0    3466
# 1    1422
# Name: Passport, dtype: int64
#
# PitchSatisfactionScore
# 3    1478
# 5     970
# 1     942
# 4     912
# 2     586
# Name: PitchSatisfactionScore, dtype: int64
#
# OwnCar
# 1    3032
# 0    1856
# Name: OwnCar, dtype: int64
#
# NumberOfChildrenVisited
# 1.0    2146
# 2.0    1335
# 0.0    1082
# 3.0     325
# Name: NumberOfChildrenVisited, dtype: int64
#
# Designation
# Executive         1842
# Manager           1732
# Senior Manager     742
# AVP                342
# VP                 230
# Name: Designation, dtype: int64
#
# MonthlyIncome
# 22347.0    235
# 21020.0      7
# 20855.0      7
# 21288.0      7
# 17342.0      7
#           ...
# 19507.0      1
# 24148.0      1
# 21108.0      1
# 24924.0      1
# 1000.0       1
# Name: MonthlyIncome, Length: 2475, dtype: int64
#
# ProdTaken
# 0    3968
# 1     920
# Name: ProdTaken, dtype: int64

# %%
col = ['TypeofContact','CityTier','Occupation','Gender','NumberOfFollowups','ProductPitched','PreferredPropertyStar','MaritalStatus']

# %%
CatFr = [feature for feature in df.columns if df[feature].dtype == 'O']
NumFr = [feature for feature in df.columns if df[feature].dtype != 'O']

# %%
NumFr
# Out:
# ['Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisited',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisited',
#  'MonthlyIncome',
#  'ProdTaken']

# %%
for i in NumFr:
    print(i)
    print(df[i].value_counts())
    print()
# Out:
# Age
# 36.0    457
# 35.0    237
# 34.0    211
# 31.0    203
# 30.0    199
# 32.0    197
# 33.0    189
# 37.0    185
# 29.0    178
# 38.0    176
# 41.0    155
# 39.0    150
# 28.0    147
# 40.0    146
# 42.0    142
# 27.0    138
# 43.0    130
# 46.0    121
# 45.0    116
# 26.0    106
# 44.0    105
# 51.0     90
# 47.0     88
# 50.0     86
# 25.0     74
# 52.0     68
# 53.0     66
# 48.0     65
# 49.0     65
# 55.0     64
# 54.0     61
# 56.0     58
# 24.0     56
# 22.0     46
# 23.0     46
# 59.0     44
# 21.0     41
# 20.0     38
# 19.0     32
# 58.0     31
# 60.0     29
# 57.0     29
# 18.0     14
# 61.0      9
# Name: Age, dtype: int64
#
# CityTier
# 1    3190
# 3    1500
# 2     198
# Name: CityTier, dtype: int64
#
# DurationOfPitch
# 9.0      483
# 13.0     474
# 7.0      342
# 8.0      333
# 6.0      307
# 16.0     274
# 15.0     269
# 14.0     253
# 10.0     244
# 11.0     205
# 12.0     195
# 17.0     172
# 30.0      95
# 22.0      89
# 31.0      83
# 23.0      79
# 18.0      75
# 32.0      74
# 29.0      74
# 21.0      73
# 25.0      73
# 27.0      72
# 26.0      72
# 24.0      70
# 35.0      66
# 20.0      65
# 28.0      61
# 33.0      57
# 19.0      57
# 34.0      50
# 36.0      44
# 5.0        6
# 126.0      1
# 127.0      1
# Name: DurationOfPitch, dtype: int64
#
# NumberOfPersonVisited
# 3    2402
# 2    1418
# 4    1026
# 1      39
# 5       3
# Name: NumberOfPersonVisited, dtype: int64
#
# NumberOfFollowups
# 4.0    2113
# 3.0    1466
# 5.0     768
# 2.0     229
# 1.0     176
# 6.0     136
# Name: NumberOfFollowups, dtype: int64
#
# PreferredPropertyStar
# 3.0    3019
# 5.0     956
# 4.0     913
# Name: PreferredPropertyStar, dtype: int64
#
# NumberOfTrips
# 2.0     1464
# 3.0     1219
# 1.0      620
# 4.0      478
# 5.0      458
# 6.0      322
# 7.0      218
# 8.0      105
# 21.0       1
# 19.0       1
# 22.0       1
# 20.0       1
# Name: NumberOfTrips, dtype: int64
#
# Passport
# 0    3466
# 1    1422
# Name: Passport, dtype: int64
#
# PitchSatisfactionScore
# 3    1478
# 5     970
# 1     942
# 4     912
# 2     586
# Name: PitchSatisfactionScore, dtype: int64
#
# OwnCar
# 1    3032
# 0    1856
# Name: OwnCar, dtype: int64
#
# NumberOfChildrenVisited
# 1.0    2146
# 2.0    1335
# 0.0    1082
# 3.0     325
# Name: NumberOfChildrenVisited, dtype: int64
#
# MonthlyIncome
# 22347.0    235
# 21020.0      7
# 20855.0      7
# 21288.0      7
# 17342.0      7
#           ...
# 19507.0      1
# 24148.0      1
# 21108.0      1
# 24924.0      1
# 1000.0       1
# Name: MonthlyIncome, Length: 2475, dtype: int64
#
# ProdTaken
# 0    3968
# 1     920
# Name: ProdTaken, dtype: int64

# %%
smallValueFeature = ['TypeofContact','Occupation','Gender','ProductPitched','MaritalStatus','Designation',
                     'CityTier','NumberOfPersonVisited','NumberOfFollowups','PreferredPropertyStar',
                     'Passport','PitchSatisfactionScore','OwnCar','NumberOfChildrenVisited']

longValueFeature = ['Age','DurationOfPitch','NumberOfTrips','MonthlyIncome']

# %%
data=df[df.ProdTaken==1]

plt.figure(figsize=(15,22))
for i in enumerate(smallValueFeature):
    plt.subplot(5,3,i[0]+1)
    sns.countplot(data=data,x = data['ProdTaken'],hue=data[i[1]])

# %% [markdown]
# #Obvservations
# #
# 1) Self Enquiry customer is morelikely to buy a product than Company Invited
# #
# 2) Saliried and Small business owners are more likely to buy a product
# #
# 3) Male are frequent traveller than Female
# #
# 4) People are opting Basic product than premium
# #
# 5) Unmarried people are more likey to travel
# 6) Exectives have bought more pakcage than anyone else
# 7) Tier One City are more frequent Traveller
# 8) Family of 3 are more frequest traveller
# 9) Folloup 4 has more conversions
# 10) Three start is most popular Hotel
# 11) passort holders have bough more packages
# 12) car Owners have more chances of travel.
# 13) Family with one child have bough more product
# ###

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=df[df['ProdTaken']==1],x='Age',kde=True,hue=df['Gender'],multiple='dodge',shrink=0.9)
plt.title("Age",fontsize = 30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b613df435b7f> in <module>
# ----> 1 plt.figure(figsize=(15,5))
#       2 sns.histplot(data=df[df['ProdTaken']==1],x='Age',kde=True,hue=df['Gender'],multiple='dodge',shrink=0.9)
#       3 plt.title("Age",fontsize = 30)
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(15,5))

sns.histplot(data=df[df['ProdTaken']==1],x='Age',hue=df['Gender'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(15,5))

sns.countplot(data=df[df['ProdTaken']==1],x='Designation')
# Out:
# <AxesSubplot:xlabel='Designation', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x=df['MonthlyIncome'],width=.7)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x=df['NumberOfTrips'],width=.7)
# Out:
# <AxesSubplot:xlabel='NumberOfTrips'>

# %%
plt.figure(figsize=(20,5))
sns.boxplot(y=df['MaritalStatus'],x=df['MonthlyIncome'],width=.7)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='MaritalStatus'>

# %%
plt.figure(figsize=(10,10))
sns.violinplot(y=df['MonthlyIncome'],x=df['MaritalStatus'],hue=df['Gender'])
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='MonthlyIncome'>

# %%
sns.stripplot(y=df['MonthlyIncome'],x=df['Occupation'],jitter=0.3,linewidth=0.5,hue=df['Gender'],dodge=True)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='MonthlyIncome'>

# %%
df['MaritalStatus'].value_counts()
# Out:
# Married      2340
# Unmarried    1598
# Divorced      950
# Name: MaritalStatus, dtype: int64

# %%
df.head(3).T
# Out:
#                                     0                1             2
# Age                                41               49            37
# TypeofContact            Self Enquiry  Company Invited  Self Enquiry
# CityTier                            3                1             1
# DurationOfPitch                     6               14             8
# Occupation                   Salaried         Salaried   Free Lancer
# Gender                         Female             Male          Male
# NumberOfPersonVisited               3                3             3
# NumberOfFollowups                   3                4             4
# ProductPitched                 Deluxe           Deluxe         Basic
# PreferredPropertyStar               3                4             3
# MaritalStatus               Unmarried         Divorced     Unmarried
# NumberOfTrips                       1                2             7
# Passport                            1                0             1
# PitchSatisfactionScore              2                3             3
# OwnCar                              1                1             0
# NumberOfChildrenVisited             0                2             0
# Designation                   Manager          Manager     Executive
# MonthlyIncome                   20993            20130         17090
# ProdTaken                           1                0             1

# %%
df.head()

X= df.iloc[:,:-1]
X
y = df.loc[:,'ProdTaken']
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 4883    1
# 4884    1
# 4885    1
# 4886    1
# 4887    1
# Name: ProdTaken, Length: 4888, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
X_train.to_csv("X_train1.csv")
X_test.to_csv("X_test2.csv")

# %%
X_train = pd.get_dummies(X_train, columns = ['TypeofContact','Occupation','Gender','MaritalStatus'],drop_first=True)

# %%
X_train
# Out:
#        Age  CityTier  DurationOfPitch  NumberOfPersonVisited  \
# 3995  36.0         1              7.0                      2
# 2610  42.0         1             21.0                      3
# 3083  50.0         1              7.0                      3
# 3973  38.0         1              7.0                      3
# 4044  44.0         1             35.0                      4
# ...    ...       ...              ...                    ...
# 4426  28.0         1             10.0                      3
# 466   41.0         3              8.0                      3
# 3092  38.0         3             28.0                      3
# 3772  28.0         3             30.0                      3
# 860   22.0         1              9.0                      2
#
#       NumberOfFollowups ProductPitched  PreferredPropertyStar  NumberOfTrips  \
# 3995                5.0          Basic                    3.0            3.0
# 2610                4.0          Basic                    3.0            6.0
# 3083                4.0          Basic                    5.0            4.0
# 3973                5.0         Deluxe                    3.0            3.0
# 4044                2.0          Basic                    3.0            6.0
# ...                 ...            ...                    ...            ...
# 4426                5.0          Basic                    3.0            2.0
# 466                 3.0   Super Deluxe                    5.0            1.0
# 3092                4.0          Basic                    3.0            7.0
# 3772                5.0         Deluxe                    3.0            3.0
# 860                 4.0          Basic                    3.0            1.0
#
#       Passport  PitchSatisfactionScore  ...  NumberOfChildrenVisited  \
# 3995         0                       4  ...                      1.0
# 2610         0                       4  ...                      2.0
# 3083         0                       4  ...                      1.0
# 3973         0                       5  ...                      1.0
# 4044         0                       3  ...                      3.0
# ...        ...                     ...  ...                      ...
# 4426         0                       1  ...                      2.0
# 466          0                       5  ...                      1.0
# 3092         0                       2  ...                      2.0
# 3772         0                       1  ...                      2.0
# 860          1                       3  ...                      0.0
#
#       Designation MonthlyIncome  TypeofContact_Self Enquiry  \
# 3995    Executive       21537.0                           1
# 2610    Executive       21129.0                           1
# 3083    Executive       22258.0                           1
# 3973      Manager       24671.0                           1
# 4044    Executive       23417.0                           0
# ...           ...           ...                         ...
# 4426    Executive       20723.0                           1
# 466           AVP       31595.0                           1
# 3092    Executive       21651.0                           0
# 3772      Manager       22218.0                           1
# 860     Executive       17853.0                           0
#
#       Occupation_Large Business  Occupation_Salaried  \
# 3995                          0                    0
# 2610                          0                    1
# 3083                          1                    0
# 3973                          0                    1
# 4044                          0                    0
# ...                         ...                  ...
# 4426                          0                    0
# 466                           0                    1
# 3092                          0                    0
# 3772                          0                    0
# 860                           0                    1
#
#       Occupation_Small Business  Gender_Male  MaritalStatus_Married  \
# 3995                          1            1                      0
# 2610                          0            1                      1
# 3083                          0            0                      0
# 3973                          0            1                      1
# 4044                          1            0                      0
# ...                         ...          ...                    ...
# 4426                          1            1                      0
# 466                           0            0                      0
# 3092                          1            0                      0
# 3772                          1            0                      1
# 860                           0            1                      0
#
#       MaritalStatus_Unmarried
# 3995                        1
# 2610                        0
# 3083                        0
# 3973                        0
# 4044                        1
# ...                       ...
# 4426                        1
# 466                         0
# 3092                        0
# 3772                        0
# 860                         0
#
# [3910 rows x 21 columns]

# %%
X_train_Ord = X_train[['ProductPitched','Designation']]
X_train_Ord
# Out:
#      ProductPitched Designation
# 3995          Basic   Executive
# 2610          Basic   Executive
# 3083          Basic   Executive
# 3973         Deluxe     Manager
# 4044          Basic   Executive
# ...             ...         ...
# 4426          Basic   Executive
# 466    Super Deluxe         AVP
# 3092          Basic   Executive
# 3772         Deluxe     Manager
# 860           Basic   Executive
#
# [3910 rows x 2 columns]

# %%
df['Designation'].unique()
# Out:
# array(['Manager', 'Executive', 'Senior Manager', 'AVP', 'VP'],
#       dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=[['Basic','Deluxe','Standard', 'Super Deluxe', 'King'],['Executive','Manager','Senior Manager', 'AVP', 'VP']])
oe
# Out:
# OrdinalEncoder(categories=[['Basic', 'Deluxe', 'Standard', 'Super Deluxe',
#                             'King'],
#                            ['Executive', 'Manager', 'Senior Manager', 'AVP',
#                             'VP']])

# %%
X_train[['ProductPitched','Designation']]  = oe.fit_transform(X_train_Ord)
X_train[['ProductPitched','Designation']]
# Out:
#       ProductPitched  Designation
# 3995             0.0          0.0
# 2610             0.0          0.0
# 3083             0.0          0.0
# 3973             1.0          1.0
# 4044             0.0          0.0
# ...              ...          ...
# 4426             0.0          0.0
# 466              3.0          3.0
# 3092             0.0          0.0
# 3772             1.0          1.0
# 860              0.0          0.0
#
# [3910 rows x 2 columns]

# %%
X_test = pd.get_dummies(X_test, columns = ['TypeofContact','Occupation','Gender','MaritalStatus'],drop_first=True)

X_test
# Out:
#        Age  CityTier  DurationOfPitch  NumberOfPersonVisited  \
# 144   32.0         3             13.0                      2
# 79    46.0         2             11.0                      3
# 2098  37.0         3             22.0                      3
# 4738  43.0         1             36.0                      3
# 2858  25.0         3              7.0                      4
# ...    ...       ...              ...                    ...
# 2908  38.0         1              7.0                      3
# 2059  29.0         1              6.0                      2
# 4872  35.0         1             24.0                      3
# 843   26.0         1             13.0                      2
# 2572  23.0         1              9.0                      4
#
#       NumberOfFollowups ProductPitched  PreferredPropertyStar  NumberOfTrips  \
# 144                 5.0         Deluxe                    3.0            1.0
# 79                  4.0         Deluxe                    4.0            1.0
# 2098                4.0         Deluxe                    3.0            5.0
# 4738                6.0         Deluxe                    3.0            6.0
# 2858                4.0          Basic                    4.0            3.0
# ...                 ...            ...                    ...            ...
# 2908                4.0       Standard                    3.0            6.0
# 2059                4.0          Basic                    5.0            2.0
# 4872                5.0          Basic                    3.0            2.0
# 843                 1.0          Basic                    3.0            2.0
# 2572                4.0          Basic                    3.0            2.0
#
#       Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisited  \
# 144          0                       2       0                      1.0
# 79           1                       5       0                      1.0
# 2098         0                       5       1                      0.0
# 4738         0                       3       1                      2.0
# 2858         1                       4       1                      3.0
# ...        ...                     ...     ...                      ...
# 2908         0                       5       1                      2.0
# 2059         1                       1       0                      0.0
# 4872         1                       5       1                      2.0
# 843          0                       5       1                      1.0
# 2572         0                       5       1                      3.0
#
#          Designation  MonthlyIncome  TypeofContact_Self Enquiry  \
# 144          Manager        19668.0                           0
# 79           Manager        20021.0                           1
# 2098         Manager        21334.0                           1
# 4738         Manager        22950.0                           1
# 2858       Executive        21880.0                           1
# ...              ...            ...                         ...
# 2908  Senior Manager        26169.0                           1
# 2059       Executive        17319.0                           1
# 4872       Executive        27178.0                           0
# 843        Executive        22347.0                           1
# 2572       Executive        21201.0                           1
#
#       Occupation_Salaried  Occupation_Small Business  Gender_Male  \
# 144                     0                          1            1
# 79                      0                          1            1
# 2098                    0                          1            1
# 4738                    0                          1            1
# 2858                    0                          0            0
# ...                   ...                        ...          ...
# 2908                    0                          0            0
# 2059                    1                          0            0
# 4872                    0                          0            1
# 843                     0                          1            1
# 2572                    0                          0            1
#
#       MaritalStatus_Married  MaritalStatus_Unmarried
# 144                       1                        0
# 79                        1                        0
# 2098                      1                        0
# 4738                      0                        1
# 2858                      0                        1
# ...                     ...                      ...
# 2908                      0                        1
# 2059                      1                        0
# 4872                      1                        0
# 843                       0                        0
# 2572                      0                        0
#
# [978 rows x 20 columns]

# %%
X_test_Ord = X_test[['ProductPitched','Designation']]
X_test_Ord
# Out:
#      ProductPitched     Designation
# 144          Deluxe         Manager
# 79           Deluxe         Manager
# 2098         Deluxe         Manager
# 4738         Deluxe         Manager
# 2858          Basic       Executive
# ...             ...             ...
# 2908       Standard  Senior Manager
# 2059          Basic       Executive
# 4872          Basic       Executive
# 843           Basic       Executive
# 2572          Basic       Executive
#
# [978 rows x 2 columns]

# %%
df['Designation'].unique()
# Out:
# array(['Manager', 'Executive', 'Senior Manager', 'AVP', 'VP'],
#       dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

oes = OrdinalEncoder(categories=[['Basic','Deluxe','Standard', 'Super Deluxe', 'King'],['Executive','Manager','Senior Manager', 'AVP', 'VP']])
oes
# Out:
# OrdinalEncoder(categories=[['Basic', 'Deluxe', 'Standard', 'Super Deluxe',
#                             'King'],
#                            ['Executive', 'Manager', 'Senior Manager', 'AVP',
#                             'VP']])

# %%
X_test[['ProductPitched','Designation']]  = oes.fit_transform(X_test_Ord)

X_test[['ProductPitched','Designation']]
# Out:
#       ProductPitched  Designation
# 144              1.0          1.0
# 79               1.0          1.0
# 2098             1.0          1.0
# 4738             1.0          1.0
# 2858             0.0          0.0
# ...              ...          ...
# 2908             2.0          2.0
# 2059             0.0          0.0
# 4872             0.0          0.0
# 843              0.0          0.0
# 2572             0.0          0.0
#
# [978 rows x 2 columns]

# %%
X_test.columns
# Out:
# Index(['Age', 'CityTier', 'DurationOfPitch', 'NumberOfPersonVisited',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisited', 'Designation', 'MonthlyIncome',
#        'TypeofContact_Self Enquiry', 'Occupation_Salaried',
#        'Occupation_Small Business', 'Gender_Male', 'MaritalStatus_Married',
#        'MaritalStatus_Unmarried'],
#       dtype='object')

# %%
abc = X_test.columns

# %%
for i in abc:
    print(i)
# Out:
# Age
# CityTier
# DurationOfPitch
# NumberOfPersonVisited
# NumberOfFollowups
# ProductPitched
# PreferredPropertyStar
# NumberOfTrips
# Passport
# PitchSatisfactionScore
# OwnCar
# NumberOfChildrenVisited
# Designation
# MonthlyIncome
# TypeofContact_Self Enquiry
# Occupation_Salaried
# Occupation_Small Business
# Gender_Male
# MaritalStatus_Married
# MaritalStatus_Unmarried
