# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/NeilPandey/Test_Dataset/master/insurance.csv')

df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.columns

dfCol = ['age', 'sex', 'bmi', 'children', 'smoker', 'region']
dfCol
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region']

# %%
for i in dfCol:
    print()
    print(i.upper())
    
    print((df[i].value_counts()).T)
    
    print()
# Out:
# AGE
# 18    69
# 19    68
# 51    29
# 45    29
# 46    29
# 47    29
# 48    29
# 50    29
# 52    29
# 20    29
# 26    28
# 54    28
# 53    28
# 25    28
# 24    28
# 49    28
# 23    28
# 22    28
# 21    28
# 27    28
# 28    28
# 31    27
# 29    27
# 30    27
# 41    27
# 43    27
# 44    27
# 40    27
# 42    27
# 57    26
# 34    26
# 33    26
# 32    26
# 56    26
# 55    26
# 59    25
# 58    25
# 39    25
# 38    25
# 35    25
# 36    25
# 37    25
# 63    23
# 60    23
# 61    23
# 62    23
# 64    22
# Name: age, dtype: int64
#
#
# SEX
# male      676
# female    662
# Name: sex, dtype: int64
#
#
# BMI
# 32.300    13
# 28.310     9
# 31.350     8
# 30.800     8
# 30.875     8
#           ..
# 20.100     1
# 29.545     1
# 37.900     1
# 25.520     1
# 24.090     1
# Name: bmi, Length: 548, dtype: int64
#
#
# CHILDREN
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
#
#
# SMOKER
# no     1064
# yes     274
# ...

# %%
for i in dfCol:
    print()
    print(i.upper())
    abc = list(df[i].unique())
    print(abc)
    
    print()
# Out:
# AGE
# [19, 18, 28, 33, 32, 31, 46, 37, 60, 25, 62, 23, 56, 27, 52, 30, 34, 59, 63, 55, 22, 26, 35, 24, 41, 38, 36, 21, 48, 40, 58, 53, 43, 64, 20, 61, 44, 57, 29, 45, 54, 49, 47, 51, 42, 50, 39]
#
#
# SEX
# ['female', 'male']
#
#
# BMI
# ...

# %%
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
numeric_Feature = [feature for feature in df.columns if df[feature].dtype != 'O' ]
categorical_Feature = [feature for feature in df.columns if df[feature].dtype == 'O']

# %%
print('We have {} Numerical Columns : {}'.format(len(numeric_Feature),numeric_Feature))
print('we have {} Caltegorical Columns {}'.format(len(categorical_Feature),categorical_Feature))
# Out:
# We have 4 Numerical Columns : ['age', 'bmi', 'children', 'charges']
# we have 3 Caltegorical Columns ['sex', 'smoker', 'region']

# %%
for i in enumerate(categorical_Feature):
    print(i[1])
# Out:
# sex
# smoker
# region

# %%
plt.figure(figsize=(15,5))
for i in enumerate(categorical_Feature):
    plt.subplot(1,3,i[0]+1)
    sns.countplot(df[i[1]],data=df)

# %%
plt.figure(figsize=(15,5))
for i in enumerate(categorical_Feature):
    plt.subplot(1,3,i[0]+1)
    sns.barplot(df[i[1]],y = df['charges'])

# %%
plt.figure(figsize=(15,5))
for i in enumerate(categorical_Feature):
    plt.subplot(1,3,i[0]+1)
    sns.barplot(df[i[1]],y = df['bmi'])

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,1,1)
sns.histplot(data=df,x='age',bins=30,kde=True,color='g')
plt.subplot(2,1,2)
sns.histplot(data=df,x='age',kde=True,hue='sex')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(20,5))
plt.subplot(141)
sns.histplot(data=df,x='sex',kde=True,hue='smoker')
plt.title("Male & Female",fontsize = 30)

plt.subplot(142)
ax = sns.histplot(data=df[df.sex=='male'],x='age',kde=True,hue='smoker')
plt.title("Male",fontsize = 30)

plt.subplot(143)
ax = sns.histplot(data=df[df.sex=='female'],x='age',kde=True,hue='smoker')
plt.title("Female",fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Female')

# %%
hue_order = ['yes', 'no']
plt.figure(figsize=(30,5))
plt.subplot(142)
ax = sns.histplot(data=df[df.sex=='male'],x='age',kde=True,hue='smoker',multiple="stack",hue_order=hue_order)
plt.title("Male",fontsize = 30)


plt.subplot(143)
ax = sns.histplot(data=df[df.sex=='female'],x='age',kde=True,hue='smoker',multiple="stack",hue_order=hue_order)
plt.title("Female",fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Female')

# %%
hue_order = ['male', 'female']
plt.figure(figsize=(30,5))
plt.subplot(142)
ax = sns.histplot(data=df[df.smoker=='yes'],x='age',kde=True,hue='sex',multiple="stack",hue_order=hue_order)
plt.title("Smokers",fontsize = 30)


plt.subplot(143)
ax = sns.histplot(data=df[df.smoker=='no'],x='age',kde=True,hue='sex',multiple="stack",hue_order=hue_order)
plt.title("NonSmokers",fontsize = 30)
# Out:
# Text(0.5, 1.0, 'NonSmokers')

# %%
sns.countplot(data = df, x=df['sex'],hue=df['smoker'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(18,8))
plt.subplot(1, 3, 1)
plt.title('BMI')
sns.violinplot(data=df,y='bmi',color='red',linewidth=3)
plt.subplot(1, 3, 2)
plt.title('Children')
sns.violinplot(data=df,y='children',color='g')
plt.subplot(1, 3, 3)
plt.title('AGE')
sns.violinplot(data=df,y='age',color='yellow')
# Out:
# <AxesSubplot:title={'center':'AGE'}, ylabel='age'>

# %%
plt.rcParams['figure.figsize'] = (30, 12)

plt.subplot(1, 2, 1)
size = df['sex'].value_counts()
labels = 'female', 'male'
color = ['red','green']


plt.pie(size,labels=labels,autopct = '.%2f%%')
plt.title('sex', fontsize = 40)

plt.subplot(1, 2, 2)
size = df['smoker'].value_counts()
labels = 'yes', 'no'

plt.pie(size,labels = labels,autopct = '.%2f%%')
plt.title('smoker', fontsize = 20)
plt.axis('off')
# Out:
# (-1.25, 1.25, -1.25, 1.25)

# %%
#####  Insights
#- Number of Male and Female is almost equal
#- smoker are more than non smoker

# %%
#### 4.4 Feature Wise Visualization
#### 4.4.1 GENDER COLUMN
#- How is distribution of Gender ?
#### UNIVARIATE ANALYSIS ( How is distribution of Gender ? )
f,ax=plt.subplots(1,2,figsize=(20,10))


sns.countplot(x=df['sex'],data=df,palette ='bright',ax=ax[0],saturation=0.95)

plt.pie(x=df['sex'].value_counts(),labels=['male','female'],explode=[0,0.1],autopct='%1.1f%%',shadow=True,colors=['#ff4d4d','#ff8000'])
plt.show()
#### Insights 
#- Gender has balanced data

# %%
#### BIVARIATE ANALYSIS ( Is gender has any impact on BMI Chidren & Charges ? ) 
gender_group = df.groupby('sex').mean()
gender_group
# Out:
#               age        bmi  children       charges
# sex
# female  39.503021  30.377749  1.074018  12569.578844
# male    38.917160  30.943129  1.115385  13956.751178

# %%
plt.figure(figsize=(10, 8))

X = ['Average']

female_scores = [gender_group['bmi'][0], gender_group['charges'][0]]
male_scores = [gender_group['bmi'][1], gender_group['charges'][1]]

X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, male_scores, 0.4, label = 'male')
plt.bar(X_axis + 0.2, female_scores, 0.4, label = 'female')
  
plt.xticks(X_axis, X)
plt.ylabel("Charges")
plt.title("Total bmi v/s charges marks of both the genders", fontweight='bold')
plt.legend()
plt.show()

# %%
Group_data2=df.groupby('region')
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.barplot(x=Group_data2['bmi'].mean().index,y=Group_data2['bmi'].mean().values,palette = 'mako',ax=ax[0])
ax[0].set_title('BMI',color='#005ce6',size=20)


sns.barplot(x=Group_data2['children'].mean().index,y=Group_data2['children'].mean().values,palette = 'flare',ax=ax[1])
ax[1].set_title('CHILDREN',color='#005ce6',size=20)


sns.barplot(x=Group_data2['age'].mean().index,y=Group_data2['age'].mean().values,palette = 'coolwarm',ax=ax[2])
ax[2].set_title('AGE',color='#005ce6',size=20)
# Out:
# Text(0.5, 1.0, 'AGE')

# %%
plt.rcParams['figure.figsize'] = (15, 9)
plt.style.use('fivethirtyeight')
sns.countplot(df['sex'], palette = 'Blues')
plt.title('GENDER', fontweight = 30, fontsize = 20)
plt.xlabel('Degree')
plt.ylabel('count')
plt.show()

# %%
df.groupby('smoker').agg('mean').plot(kind='barh',figsize=(10,10))
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
plt.subplots(1,4,figsize=(16,5))
plt.subplot(141)
sns.boxplot(df['children'],color='skyblue')
plt.subplot(142)
sns.boxplot(df['bmi'],color='hotpink')
plt.subplot(143)
sns.boxplot(df['age'],color='yellow')
plt.subplot(144)
sns.boxplot(df['charges'],color='lightgreen')
plt.show()

# %%
sns.pairplot(df,hue = 'sex')
plt.show()

# %%
abc = df.corr()

sns.heatmap(abc,cmap="YlGnBu", annot=True)
  
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
Sex = df[['sex']]
Smoker =df[['smoker']]
Region = df[['region']]
Smoker = pd.get_dummies(Smoker,drop_first=True)
Sex = pd.get_dummies(Sex,drop_first=True)
Region = pd.get_dummies(Region,drop_first=True)

df1 = pd.concat([df,Smoker,Sex,Region],axis=1)
df1.drop(['sex','smoker','region'],axis=1,inplace=True)

# %%
df.columns

Col = ['age', 'bmi', 'children',  'smoker_no', 'smoker_yes',
       'sex_female', 'sex_male', 'region_northeast', 'region_northwest',
       'region_southeast', 'region_southwest','charges']
Col
# Out:
# ['age',
#  'bmi',
#  'children',
#  'smoker_no',
#  'smoker_yes',
#  'sex_female',
#  'sex_male',
#  'region_northeast',
#  'region_northwest',
#  'region_southeast',
#  'region_southwest',
#  'charges']

# %%
newCol = ['age','bmi','children','smoker_yes','sex_male','region_northwest','region_southeast','region_southwest','charges']
df1 = df1[newCol]

# %%
abc = df1.corr()

abc
# Out:
#                        age       bmi  children  smoker_yes  sex_male  \
# age               1.000000  0.109272  0.042469   -0.025019 -0.020856
# bmi               0.109272  1.000000  0.012759    0.003750  0.046371
# children          0.042469  0.012759  1.000000    0.007673  0.017163
# smoker_yes       -0.025019  0.003750  0.007673    1.000000  0.076185
# sex_male         -0.020856  0.046371  0.017163    0.076185  1.000000
# region_northwest -0.000407 -0.135996  0.024806   -0.036945 -0.011156
# region_southeast -0.011642  0.270025 -0.023066    0.068498  0.017117
# region_southwest  0.010016 -0.006205  0.021914   -0.036945 -0.004184
# charges           0.299008  0.198341  0.067998    0.787251  0.057292
#
#                   region_northwest  region_southeast  region_southwest  \
# age                      -0.000407         -0.011642          0.010016
# bmi                      -0.135996          0.270025         -0.006205
# ...

# %%
sns.barplot(x=my_dict.keys(), y = int(str(my_dict.values())))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-0a6671777d50> in <module>
# ----> 1 sns.barplot(x=my_dict.keys(), y = int(str(my_dict.values())))
#
# NameError: name 'my_dict' is not defined

# %%
sns.heatmap(abc,cmap="YlGnBu", annot=True)
