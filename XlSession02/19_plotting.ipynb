# %%
import pandas as pd

# %%
file_path = "D://MLProjects//ZDatasets//AirlineData//Data_Train.csv"

# Read the CSV file
df = pd.read_csv(file_path)
df

# Read/Undestand the carefully
# Out:
#          Airline Date_of_Journey    Source Destination                  Route  \
# 0         IndiGo      24-03-2019  Banglore   New Delhi              BLR ? DEL
# 1      Air India      01-05-2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2    Jet Airways      09-06-2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3         IndiGo      12-05-2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4         IndiGo      01-03-2019  Banglore   New Delhi        BLR ? NAG ? DEL
# ..           ...             ...       ...         ...                    ...
# 245       IndiGo      24-04-2019  Banglore       Delhi              BLR ? DEL
# 246  Jet Airways      09-06-2019     Delhi      Cochin        DEL ? BOM ? COK
# 247       IndiGo      15-05-2019     Delhi      Cochin        DEL ? BOM ? COK
# 248      Vistara      27-06-2019   Chennai     Kolkata              MAA ? CCU
# 249     SpiceJet      06-06-2019     Delhi      Cochin        DEL ? PNQ ? COK
#
#     Dep_Time      Arrival_Time Duration Total_Stops  \
# 0      22:20  22-03-2023 01:10   2h 50m    non-stop
# 1      05:50             13:15   7h 25m     2 stops
# 2      09:25  10-06-2023 04:25      19h     2 stops
# 3      18:05             23:30   5h 25m      1 stop
# 4      16:50             21:35   4h 45m      1 stop
# ..       ...               ...      ...         ...
# 245    23:30  25-04-2023 02:20   2h 50m    non-stop
# 246    19:15  10-06-2023 04:25   9h 10m      1 stop
# 247    10:35             21:00  10h 25m      1 stop
# 248    17:45             20:05   2h 20m    non-stop
# 249    08:45             13:15   4h 30m      1 stop
#
#                  Additional_Info  Price
# 0                        No info   3897
# 1                        No info   7662
# 2                        No info  13882
# 3                        No info   6218
# 4                        No info  13302
# ..                           ...    ...
# 245                      No info   3943
# 246  In-flight meal not included  10577
# 247                      No info   6979
# 248                      No info  11982
# 249                      No info   5264
#
# [250 rows x 11 columns]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24-03-2019  Banglore   New Delhi              BLR ? DEL
# 1    Air India      01-05-2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways      09-06-2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      12-05-2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      01-03-2019  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time      Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  22-03-2023 01:10   2h 50m    non-stop         No info   3897
# 1    05:50             13:15   7h 25m     2 stops         No info   7662
# 2    09:25  10-06-2023 04:25      19h     2 stops         No info  13882
# 3    18:05             23:30   5h 25m      1 stop         No info   6218
# 4    16:50             21:35   4h 45m      1 stop         No info  13302

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\shivraj shinde\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df['Airline'],df['Price'])
plt.show()

# %%
# Apply Label

plt.bar(df['Airline'],df['Price'])
plt.xlabel("Airline")
plt.ylabel('Price')


plt.show()

# %%
# Apply Title

plt.bar(df['Airline'],df['Price'])
plt.xlabel("Airline")
plt.ylabel('Price')
plt.title("Airline Vs Price")

plt.show()

# %%
# Apply Title

plt.bar(df['Airline'],df['Price'])
plt.xlabel("Airline")
plt.ylabel('Price')
plt.title("Airline Vs Price")
plt.xticks(rotation=45)
plt.show()

# %%
# Apply FontSize
sizeOfFont = 15
plt.bar(df['Airline'],df['Price'])
plt.xlabel("Airline",fontsize=sizeOfFont)
plt.ylabel('Price',fontsize=sizeOfFont)
plt.title("Airline Vs Price",fontsize=sizeOfFont)
plt.xticks(rotation=45)
plt.show()

# %%
# Playing the parameters
# matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center')
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
sizeOfFont = 15
plt.bar(df['Airline'],df['Price'],width=.5,align='center')
plt.xlabel("Airline",fontsize=sizeOfFont)
plt.ylabel('Price',fontsize=sizeOfFont)
plt.title("Airline Vs Price",fontsize=sizeOfFont)
plt.xticks(rotation=45)
plt.show()

# %%
# change Color
import matplotlib.pyplot as plt
sizeOfFont = 15
plt.bar(df['Airline'],df['Price'],width=.5,align='center',color='c')
plt.xlabel("Airline",fontsize=sizeOfFont)
plt.ylabel('Price',fontsize=sizeOfFont)
plt.title("Airline Vs Price",fontsize=sizeOfFont)
plt.xticks(rotation=45)
plt.show()

# %%
# Color
import matplotlib.pyplot as plt
#colourValue = ['y','b','g','r','y','b','g','r']
colourValue = ['y','b','g','r','y','b','g','r']

# change Color
import matplotlib.pyplot as plt
sizeOfFont = 15
plt.bar(df['Airline'],df['Price'],width=.5,align='center',color=colourValue)
plt.xlabel("Airline",fontsize=sizeOfFont)
plt.ylabel('Price',fontsize=sizeOfFont)
plt.title("Airline Vs Price",fontsize=sizeOfFont)
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Seaborn

# %%
pip install seaborn

# %%
import seaborn as sns
sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent')
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
sns.barplot(x=df['Airline'],y=df['Price'])
plt.show()

# %%
import seaborn as sns
sns.barplot(x=df['Airline'],y=df['Price'])
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent',ci=None)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SHIVRAJ SHINDE\AppData\Local\Temp\ipykernel_14436\3644847344.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent',ci=None)

# %%
# sort OR arrange Alphabitically
import seaborn as sns

AirlinSortedList = ['Air Asia','Air India','GoAir','IndiGo','Jet Airways','Multiple carriers','SpiceJet','Vistara']

sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent',ci=None,hue_order=AirlinSortedList)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SHIVRAJ SHINDE\AppData\Local\Temp\ipykernel_14436\2353332705.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent',ci=None,hue_order=AirlinSortedList)

# %%
# Out:
# Airline
# Air Asia               15658
# Air India             373477
# GoAir                  57031
# IndiGo                272407
# Jet Airways          1007932
# Multiple carriers     336367
# SpiceJet               65597
# Vistara               109064
# Name: Price, dtype: int64

# %%
# plot graph based on Sorted Price

df01 = df.groupby('Airline')['Price'].sum()
df01 = df01.sort_values(ascending=True)
df01 = pd.DataFrame({'Airline': df01_sorted.index, 'Price': df01_sorted.values})

sns.barplot(x=df01['Airline'],y=df01['Price'],palette='Accent',ci=None)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SHIVRAJ SHINDE\AppData\Local\Temp\ipykernel_14436\469981656.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df01['Airline'],y=df01['Price'],palette='Accent',ci=None)

# %%
# make plot horizontal

import seaborn as sns
sns.barplot(y=df['Airline'],x=df['Price'],palette='Accent',ci=None)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SHIVRAJ SHINDE\AppData\Local\Temp\ipykernel_14436\3295067861.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(y=df['Airline'],x=df['Price'],palette='Accent',ci=None)

# %%
# Add Hue of Source

import seaborn as sns

plt.figure(figsize=(15,5))

sns.barplot(x=df['Airline'],y=df['Price'],hue= df['Source'],ci=None)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SHIVRAJ SHINDE\AppData\Local\Temp\ipykernel_14436\3520678118.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['Airline'],y=df['Price'],hue= df['Source'],ci=None)

# %% [markdown]
# # CountPlot

# %%
import seaborn as sns

plt.figure(figsize=(15,5))
sns.countplot(x=df['Destination'],hue=df['Airline'])
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.lineplot(y=df['Price'],x=df['Airline'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.lineplot(y=df['Price'],x=df['Airline'],hue=df['Source'])
plt.show()

# %%
sns.scatterplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
sns.scatterplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
sns.scatterplot(y=df['Price'],x=df['Airline'])
# Out:
# <Axes: xlabel='Airline', ylabel='Price'>

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x=df['Price'])
# Out:
# <Axes: xlabel='Price'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x=df['Price'],y=df['Airline'])
# Out:
# <Axes: xlabel='Price', ylabel='Airline'>

# %%
plt.figure(figsize=(15,5))
sns.violinplot(x=df['Price'])
# Out:
# <Axes: xlabel='Price'>

# %%
plt.figure(figsize=(15,10))
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Price'],kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.swarmplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>
